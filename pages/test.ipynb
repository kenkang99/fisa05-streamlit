# %%
'ㅉ' in '짱 구'
# Out:
# False

# %%
# https://hello-yeonji-stock.streamlit.app/

# 표준 라이브러리
import datetime
from io import BytesIO

# 서드파티 라이브러리
import streamlit as st
import pandas as pd
import FinanceDataReader as fdr
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib 
import koreanize_matplotlib

# 캐싱: 인자가 바뀌지 않는 함수 실행 결과를 저장 후 재사용
@st.cache_data # streamlit에서 사용할 것임
def get_krx_company_list() -> pd.DataFrame:
    """
    KRX(한국거래소) 상장 기업의 회사명과 종목코드 정보를 DataFrame으로 반환합니다.

    Returns:
        pd.DataFrame: '회사명', '종목코드' 컬럼을 가진 DataFrame
    """
    krx_df = fdr.StockListing('KRX')
    company_df = krx_df[['Name', 'Code']].rename(columns={'Name': '회사명', 'Code': '종목코드'})
    return company_df


def get_stock_code_by_company(company_name: str) -> str:
    """
    회사명을 입력받아 해당 회사의 종목코드를 반환합니다.
    Args:
        company_name (str): 조회할 회사명
    Returns:
        str: 종목코드. 입력된 회사명이 없으면 ValueError 발생
    """
    company_df = get_krx_company_list()
    codes = company_df[company_df['회사명'] == company_name]['종목코드'].values
    if len(codes) > 0:
        return codes[0]
    else:
        raise ValueError(f"'{company_name}'에 해당하는 종목코드가 없습니다.")

'''
streamlit에서 사용될 코드

def sidebar_inputs() -> tuple[str, tuple[datetime.date, datetime.date], bool]:
    """
    Streamlit 사이드바에 회사명 입력창, 날짜 선택 위젯, 확인 버튼을 생성하고 입력값을 반환합니다.

    Returns:
        tuple: (회사명(str), (시작일, 종료일)(tuple of date), 확인버튼 클릭여부(bool))
    """
    company_name = st.sidebar.text_input('회사 이름을 입력하세요: ')
    today = datetime.datetime.now()
    this_year = today.year
    jan_1 = datetime.date(this_year, 1, 1)
    selected_dates = st.sidebar.date_input(
        "시작일과 종료일을 입력하세요",
        (jan_1, today),
        None,
        today,
        format="MM.DD.YYYY",
    )
    st.sidebar.write(selected_dates)
    confirm_btn = st.sidebar.button('확인')
    return company_name, selected_dates, confirm_btn

# 우리가 필요로하는 코드조각들
stock_code = get_stock_code_by_company(company_name)
start_date = selected_dates[0].strftime(r"%Y-%m-%d")
end_date = (selected_dates[1] + datetime.timedelta(days=1)).strftime(r"%Y-%m-%d")
price_df = fdr.DataReader(f'KRX:{stock_code}', start_date, end_date)

excel_data = BytesIO()
price_df.to_excel(excel_data)
st.download_button("엑셀 파일 다운로드", excel_data, file_name='stock_data.xlsx')

'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 14
#      12 import matplotlib.pyplot as plt
#      13 import matplotlib
# ---> 14 import koreanize_matplotlib
#      16 # 캐싱: 인자가 바뀌지 않는 함수 실행 결과를 저장 후 재사용
#      17 @st.cache_data # streamlit에서 사용할 것임
#      18 def get_krx_company_list() -> pd.DataFrame:
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\koreanize_matplotlib\__init__.py:1
# ----> 1 from koreanize_matplotlib.koreanize_matplotlib import koreanize, get_font_path, get_font_ttf_path
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\koreanize_matplotlib\koreanize_matplotlib.py:5
#       3 import matplotlib
#       4 from matplotlib import font_manager
# ----> 5 from distutils.version import LooseVersion
#       7 FONTS_DIR = 'fonts'
#       8 FONT_NAME = "NanumGothic"
#
# ModuleNotFoundError: No module named 'distutils'

# %%
import requests
import json
import xml.etree.ElementTree as ET # XML 응답을 처리할 경우 필요

# 1. API 기본 정보 설정
#BASE_URL = "https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 2. 필수 요청 Parameters 설정 [2]
# !!! [인증키] 부분은 반드시 본인이 발급받은 실제 인증키로 대체해야 합니다.
# 대괄호([])는 입력하지 않습니다.
params = {
    "authKey": "4a606afd-193d-4881-a83d-510c5d586276",
    "returnType": "JSON",  # XML 또는 JSON 선택. 여기서는 JSON으로 예시 [2]
    "outType": "1",        # '1': 리스트, '2': 상세 [2]
    "pageNum": "1",        # 시작 페이지 번호 (기본값 1, 최대 1000) [2]
    "pageSize": "100",      # 페이지당 출력 건수 (기본값 10, 최대 100) [2]
    "srchTraStDt": "20230101", # 훈련 시작일의 시작 범위 (YYYYMMDD 형식) [2]
    "srchTraEndDt": "20231231", # 훈련 시작일의 종료 범위 (YYYYMMDD 형식) [2]
    "sort": "ASC",         # 정렬 방법: "ASC" (오름차순), "DESC" (내림차순) [2]
    "sortCol": "2"         # 정렬 기준 컬럼: 1(훈련기관명), 2(훈련시작일), 3(취업률), 4(만족도점수) [2]
}
BASE_URL = f"https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do?authKey={params['authKey']}&returnType=XML"


print(BASE_URL)
# 3. 선택 요청 Parameters 추가 [2]
# 예시: 훈련지역 대분류 '서울' (코드 '11') 및 훈련유형 'K-디지털 트레이닝' (코드 'C0104') 추가
# 여러 선택조건을 조합하여 사용할 수 있습니다.
optional_params = {
    "srchTraArea1": "11",   # 훈련지역 대분류: '11' 서울 [2]
    "crseTracseSe": "C0104" # 훈련유형: 'C0104' K-디지털 트레이닝 [2]
    # "srchNcs1": "20",       # NCS 직종 1차분류 코드: '20' 정보통신 [2]
    # "srchTraProcessNm": "파이썬", # 훈련과정명 검색 [2]
}

# 필수 및 선택 Parameters를 병합
params.update(optional_params)

# 4. API 호출
print("API 호출 중...")
try:
    response = requests.get(BASE_URL, params=params)
    response.raise_for_status() # HTTP 에러가 발생하면 예외를 발생시킵니다.

    # 5. 응답 데이터 처리
    if params["returnType"] == "JSON":
        data = response.json()
        print("\nAPI 호출 성공 (JSON):")
        print(data)
        # JSON 데이터 구조에 따라 접근
        if data and 'HRDNet' in data and 'srchList' in data['HRDNet']:
            # 검색된 총 건수, 현재 페이지, 페이지당 출력 개수 정보 [3]
            total_count = data['HRDNet'].get('scn_cnt', 'N/A')
            current_page = data['HRDNet'].get('pageNum', 'N/A')
            page_size = data['HRDNet'].get('pageSize', 'N/A')

            print(f"총 검색 건수: {total_count}개 [3]")
            print(f"현재 페이지: {current_page}, 페이지당 출력 개수: {page_size}개 [3]")

            # 훈련과정 목록 출력 [3]
            training_list = data['HRDNet']['srchList'].get('scn_list', [])
            if not isinstance(training_list, list): # 단일 항목일 경우 리스트가 아닌 딕셔너리로 올 수 있음
                training_list = [training_list]

            if training_list:
                print("\n검색된 훈련과정 목록:")
                for i, course in enumerate(training_list):
                    print(f"--- 훈련과정 {i+1} ---")
                    print(f"  제목: {course.get('TITLE', 'N/A')} [3]")
                    print(f"  훈련기관: {course.get('SUB_TITLE', 'N/A')} [3]")
                    print(f"  훈련 시작일: {course.get('TRA_START_DATE', 'N/A')} [3]")
                    print(f"  훈련 종료일: {course.get('TRA_END_DATE', 'N/A')} [3]")
                    print(f"  주소: {course.get('ADDRESS', 'N/A')} [3]")
                    print(f"  수강비: {course.get('COURSE_MAN', 'N/A')} [3]")
                    print(f"  실제 훈련비: {course.get('REAL_MAN', 'N/A')} [3]")
                    print(f"  취업률 (고용보험 3개월): {course.get('EI_EMPL_RATE3', 'N/A')}% [3]")
                    print(f"  만족도 점수: {course.get('STDG_SCOR', 'N/A')} [3]")
                    print("-" * 20)
            else:
                print("검색된 훈련과정이 없습니다.")
        else:
            print("API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.")
            print(data) # 전체 응답 출력하여 구조 확인
    elif params["returnType"] == "XML":
        # XML 응답을 처리할 경우
        root = ET.fromstring(response.text)
        print("\nAPI 호출 성공 (XML):")
        # XML 응답 구조에 따라 접근 [3]
        # 예시: 총 검색 건수
        scn_cnt = root.find('scn_cnt')
        if scn_cnt is not None:
            print(f"총 검색 건수: {scn_cnt.text}개 [3]")
        
        # 훈련과정 목록 (srchList/scn_list) 순회 [3]
        for course in root.findall('.//scn_list'):
            title = course.find('TITLE')
            if title is not None:
                print(f"  제목: {title.text} [3]")
            # 필요한 다른 항목들도 위와 같은 방식으로 접근하여 출력
            
    else:
        print(f"지원하지 않는 returnType: {params['returnType']}")

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP 오류 발생: {http_err}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"연결 오류 발생: {conn_err}")
except requests.exceptions.Timeout as timeout_err:
    print(f"타임아웃 오류 발생: {timeout_err}")
except requests.exceptions.RequestException as req_err:
    print(f"요청 오류 발생: {req_err}")
except json.JSONDecodeError as json_err:
    print(f"JSON 디코딩 오류: {json_err}. API 응답이 유효한 JSON 형식이 아닙니다.")
    print("응답 내용:", response.text[:500]) # 응답의 일부를 출력하여 문제 확인
except Exception as e:
    print(f"예상치 못한 오류 발생: {e}")
# Out:
# https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do?authKey=4a606afd-193d-4881-a83d-510c5d586276&returnType=XML
# API 호출 중...
# 요청 오류 발생: Expecting value: line 1 column 1 (char 0)

# %%
import requests
import json
import xml.etree.ElementTree as ET # XML 응답을 처리할 경우 필요

# 1. API 기본 정보 설정
BASE_URL = "https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 2. 필수 요청 Parameters 설정 [2]
# !!! [인증키] 부분은 반드시 본인이 발급받은 실제 인증키로 대체해야 합니다.
# 대괄호([])는 입력하지 않습니다.
params = {
    "authKey": "4a606afd-193d-4881-a83d-510c5d586276",
    "returnType": "JSON",  # XML 또는 JSON 선택. 여기서는 JSON으로 예시 [2]
    "outType": "1",        # '1': 리스트, '2': 상세 [2]
    "pageNum": "1",        # 시작 페이지 번호 (기본값 1, 최대 1000) [2]
    "pageSize": "100",      # 페이지당 출력 건수 (기본값 10, 최대 100) [2]
    "srchTraStDt": "20230101", # 훈련 시작일의 시작 범위 (YYYYMMDD 형식) [2]
    "srchTraEndDt": "20231231", # 훈련 시작일의 종료 범위 (YYYYMMDD 형식) [2]
    "sort": "ASC",         # 정렬 방법: "ASC" (오름차순), "DESC" (내림차순) [2]
    "sortCol": "2"         # 정렬 기준 컬럼: 1(훈련기관명), 2(훈련시작일), 3(취업률), 4(만족도점수) [2]
}

#BASE_URL = f"https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do?authKey={params['authKey']}&returnType=XML&outType=1&pageNum=1&pageSize=20&srchTraStDt=20141001&srchTraEndDt=20141231&sort=ASC&sortCol=2"
print(BASE_URL)
# 3. 선택 요청 Parameters 추가 [2]
# 예시: 훈련지역 대분류 '서울' (코드 '11') 및 훈련유형 'K-디지털 트레이닝' (코드 'C0104') 추가
# 여러 선택조건을 조합하여 사용할 수 있습니다.

# optional_params = {
#     "srchTraArea1": "11",   # 훈련지역 대분류: '11' 서울 [2]
#     "crseTracseSe": "C0104" # 훈련유형: 'C0104' K-디지털 트레이닝 [2]
#     # "srchNcs1": "20",       # NCS 직종 1차분류 코드: '20' 정보통신 [2]
#     # "srchTraProcessNm": "파이썬", # 훈련과정명 검색 [2]
# }

# 필수 및 선택 Parameters를 병합
# params.update(optional_params)

# 4. API 호출
print("API 호출 중...")
try:
    response = requests.get(BASE_URL, params=params)
    response.raise_for_status() # HTTP 에러가 발생하면 예외를 발생시킵니다.

    # 5. 응답 데이터 처리
    if params["returnType"] == "JSON":
        data = response.json()
        print("\nAPI 호출 성공 (JSON):")
        print(data)
        # JSON 데이터 구조에 따라 접근
        if data and 'HRDNet' in data and 'srchList' in data['HRDNet']:
            # 검색된 총 건수, 현재 페이지, 페이지당 출력 개수 정보 [3]
            total_count = data['HRDNet'].get('scn_cnt', 'N/A')
            current_page = data['HRDNet'].get('pageNum', 'N/A')
            page_size = data['HRDNet'].get('pageSize', 'N/A')

            print(f"총 검색 건수: {total_count}개 [3]")
            print(f"현재 페이지: {current_page}, 페이지당 출력 개수: {page_size}개 [3]")

            # 훈련과정 목록 출력 [3]
            training_list = data['HRDNet']['srchList'].get('scn_list', [])
            if not isinstance(training_list, list): # 단일 항목일 경우 리스트가 아닌 딕셔너리로 올 수 있음
                training_list = [training_list]

            if training_list:
                print("\n검색된 훈련과정 목록:")
                for i, course in enumerate(training_list):
                    print(f"--- 훈련과정 {i+1} ---")
                    print(f"  제목: {course.get('TITLE', 'N/A')} [3]")
                    print(f"  훈련기관: {course.get('SUB_TITLE', 'N/A')} [3]")
                    print(f"  훈련 시작일: {course.get('TRA_START_DATE', 'N/A')} [3]")
                    print(f"  훈련 종료일: {course.get('TRA_END_DATE', 'N/A')} [3]")
                    print(f"  주소: {course.get('ADDRESS', 'N/A')} [3]")
                    print(f"  수강비: {course.get('COURSE_MAN', 'N/A')} [3]")
                    print(f"  실제 훈련비: {course.get('REAL_MAN', 'N/A')} [3]")
                    print(f"  취업률 (고용보험 3개월): {course.get('EI_EMPL_RATE3', 'N/A')}% [3]")
                    print(f"  만족도 점수: {course.get('STDG_SCOR', 'N/A')} [3]")
                    print("-" * 20)
            else:
                print("검색된 훈련과정이 없습니다.")
        else:
            print("API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.")
            print(data) # 전체 응답 출력하여 구조 확인
    elif params["returnType"] == "XML":
        # XML 응답을 처리할 경우
        root = ET.fromstring(response.text)
        print("\nAPI 호출 성공 (XML):")
        # XML 응답 구조에 따라 접근 [3]
        # 예시: 총 검색 건수
        scn_cnt = root.find('scn_cnt')
        if scn_cnt is not None:
            print(f"총 검색 건수: {scn_cnt.text}개 [3]")
        
        # 훈련과정 목록 (srchList/scn_list) 순회 [3]
        for course in root.findall('.//scn_list'):
            title = course.find('TITLE')
            if title is not None:
                print(f"  제목: {title.text} [3]")
            # 필요한 다른 항목들도 위와 같은 방식으로 접근하여 출력
            
    else:
        print(f"지원하지 않는 returnType: {params['returnType']}")

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP 오류 발생: {http_err}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"연결 오류 발생: {conn_err}")
except requests.exceptions.Timeout as timeout_err:
    print(f"타임아웃 오류 발생: {timeout_err}")
except requests.exceptions.RequestException as req_err:
    print(f"요청 오류 발생: {req_err}")
except json.JSONDecodeError as json_err:
    print(f"JSON 디코딩 오류: {json_err}. API 응답이 유효한 JSON 형식이 아닙니다.")
    print("응답 내용:", response.text[:500]) # 응답의 일부를 출력하여 문제 확인
except Exception as e:
    print(f"예상치 못한 오류 발생: {e}")
# Out:
# https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do
# API 호출 중...
#
# API 호출 성공 (JSON):
# {'srchList': [{'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '모든것을뛰어넘는이기는비즈니스전략', 'realMan': '73780', 'telNo': '02-2163-5724', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '02010101', 'regCourseMan': '0', 'trprDegr': '22', 'address': '서울 성동구', 'traEndDate': '2023-02-28', 'subTitle': '(주)알파코', 'instCd': '200400456', 'trngAreaCd': '11200', 'trprId': 'ACG20213000806323', 'yardMan': '2500', 'courseMan': '73780', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020014456', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20213000806323&tracseTme=22&trainstCstmrId=500020014456&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20213000806323&tracseTme=22&trainstCstmrId=500020014456&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '[Grow+] 회사에서 인정받는 총무 실무', 'realMan': '50490', 'telNo': '031-908-1448', 'stdgScor': '94.5', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '02020101', 'regCourseMan': '0', 'trprDegr': '354', 'address': '경기 고양시 일산동구', 'traEndDate': '2023-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20213000806438', 'yardMan': '150', 'courseMan': '50490', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20213000806438&tracseTme=354&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20213000806438&tracseTme=354&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '플랜트·건설 프로젝트 통합관리의 이해 및 실무', 'realMan': '75240', 'telNo': '02-1688-2447', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '14040301', 'regCourseMan': '0', 'trprDegr': '18', 'address': '서울 금천구', 'traEndDate': '2023-01-31', 'subTitle': '(주) 올윈에듀', 'instCd': '201100060', 'trngAreaCd': '11545', 'trprId': 'ACG20223000819333', 'yardMan': '500', 'courseMan': '75240', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020024074', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20223000819333&tracseTme=18&trainstCstmrId=500020024074&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20223000819333&tracseTme=18&trainstCstmrId=500020024074&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '의료서비스 실전 직무 교육', 'realMan': '62370', 'telNo': '02-1588-6559', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '06010202', 'regCourseMan': '0', 'trprDegr': '25', 'address': '서울 구로구', 'traEndDate': '2023-01-31', 'subTitle': '(주)휴넷', 'instCd': '200200408', 'trngAreaCd': '11530', 'trprId': 'ACG20223000821134', 'yardMan': '500', 'courseMan': '62370', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020043313', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20223000821134&tracseTme=25&trainstCstmrId=500020043313&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20223000821134&tracseTme=25&trainstCstmrId=500020043313&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.wo ...
# API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.
# {'srchList': [{'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '모든것을뛰어넘는이기는비즈니스전략', 'realMan': '73780', 'telNo': '02-2163-5724', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '02010101', 'regCourseMan': '0', 'trprDegr': '22', 'address': '서울 성동구', 'traEndDate': '2023-02-28', 'subTitle': '(주)알파코', 'instCd': '200400456', 'trngAreaCd': '11200', 'trprId': 'ACG20213000806323', 'yardMan': '2500', 'courseMan': '73780', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020014456', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20213000806323&tracseTme=22&trainstCstmrId=500020014456&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20213000806323&tracseTme=22&trainstCstmrId=500020014456&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '[Grow+] 회사에서 인정받는 총무 실무', 'realMan': '50490', 'telNo': '031-908-1448', 'stdgScor': '94.5', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '02020101', 'regCourseMan': '0', 'trprDegr': '354', 'address': '경기 고양시 일산동구', 'traEndDate': '2023-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20213000806438', 'yardMan': '150', 'courseMan': '50490', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20213000806438&tracseTme=354&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20213000806438&tracseTme=354&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '플랜트·건설 프로젝트 통합관리의 이해 및 실무', 'realMan': '75240', 'telNo': '02-1688-2447', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '14040301', 'regCourseMan': '0', 'trprDegr': '18', 'address': '서울 금천구', 'traEndDate': '2023-01-31', 'subTitle': '(주) 올윈에듀', 'instCd': '201100060', 'trngAreaCd': '11545', 'trprId': 'ACG20223000819333', 'yardMan': '500', 'courseMan': '75240', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020024074', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20223000819333&tracseTme=18&trainstCstmrId=500020024074&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20223000819333&tracseTme=18&trainstCstmrId=500020024074&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '의료서비스 실전 직무 교육', 'realMan': '62370', 'telNo': '02-1588-6559', 'stdgScor': '0', 'traStartDate': '2023-01-01', 'grade': '', 'ncsCd': '06010202', 'regCourseMan': '0', 'trprDegr': '25', 'address': '서울 구로구', 'traEndDate': '2023-01-31', 'subTitle': '(주)휴넷', 'instCd': '200200408', 'trngAreaCd': '11530', 'trprId': 'ACG20223000821134', 'yardMan': '500', 'courseMan': '62370', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020043313', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20223000821134&tracseTme=25&trainstCstmrId=500020043313&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20223000821134&tracseTme=25&trainstCstmrId=500020043313&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.wo ...

# %%
import requests
import json
import xml.etree.ElementTree as ET # XML 응답을 처리할 경우 필요

# 1. API 기본 정보 설정
#BASE_URL = "https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 2. 필수 요청 Parameters 설정 [2]
# !!! [인증키] 부분은 반드시 본인이 발급받은 실제 인증키로 대체해야 합니다.
# 대괄호([])는 입력하지 않습니다.
params = {
    "authKey": "4a606afd-193d-4881-a83d-510c5d586276", # 4a606afd-193d-4881-a83d-510c5d586276
    "returnType": "JSON",  # XML 또는 JSON 선택. 여기서는 JSON으로 예시 [2]
    "outType": "1",        # '1': 리스트, '2': 상세 [2]
    "pageNum": "1",        # 시작 페이지 번호 (기본값 1, 최대 1000) [2]
    "pageSize": "100",      # 페이지당 출력 건수 (기본값 10, 최대 100) [2]
    "srchTraStDt": "20250101", # 훈련 시작일의 시작 범위 (YYYYMMDD 형식) [2]
    "srchTraEndDt": "20250716", # 훈련 시작일의 종료 범위 (YYYYMMDD 형식) [2]
    "sort": "ASC",         # 정렬 방법: "ASC" (오름차순), "DESC" (내림차순) [2]
    "sortCol": "2"         # 정렬 기준 컬럼: 1(훈련기관명), 2(훈련시작일), 3(취업률), 4(만족도점수) [2]
}

BASE_URL = f"https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 3. 선택 요청 Parameters 추가 [2]
# 예시: 훈련지역 대분류 '서울' (코드 '11') 및 훈련유형 'K-디지털 트레이닝' (코드 'C0104') 추가
# 여러 선택조건을 조합하여 사용할 수 있습니다.
# optional_params = {
#     "srchTraArea1": "11",   # 훈련지역 대분류: '11' 서울 [2]
#     "crseTracseSe": "C0104" # 훈련유형: 'C0104' K-디지털 트레이닝 [2]
#     # "srchNcs1": "20",       # NCS 직종 1차분류 코드: '20' 정보통신 [2]
#     # "srchTraProcessNm": "파이썬", # 훈련과정명 검색 [2]
# }

# # 필수 및 선택 Parameters를 병합
# params.update(optional_params)

# 4. API 호출
print("API 호출 중...")
try:
    response = requests.get(BASE_URL, params=params)
    response.raise_for_status() # HTTP 에러가 발생하면 예외를 발생시킵니다.
    print(response.text)

    # 5. 응답 데이터 처리
    if params["returnType"] == "JSON":
        data = response.json()
        print("\nAPI 호출 성공 (JSON):")
        print(data)
        # JSON 데이터 구조에 따라 접근
        if data and 'HRDNet' in data and 'srchList' in data['HRDNet']:
            # 검색된 총 건수, 현재 페이지, 페이지당 출력 개수 정보 [3]
            total_count = data['HRDNet'].get('scn_cnt', 'N/A')
            current_page = data['HRDNet'].get('pageNum', 'N/A')
            page_size = data['HRDNet'].get('pageSize', 'N/A')

            print(f"총 검색 건수: {total_count}개 [3]")
            print(f"현재 페이지: {current_page}, 페이지당 출력 개수: {page_size}개 [3]")

            # 훈련과정 목록 출력 [3]
            training_list = data['HRDNet']['srchList'].get('scn_list', [])
            if not isinstance(training_list, list): # 단일 항목일 경우 리스트가 아닌 딕셔너리로 올 수 있음
                training_list = [training_list]

            if training_list:
                print("\n검색된 훈련과정 목록:")
                for i, course in enumerate(training_list):
                    print(f"--- 훈련과정 {i+1} ---")
                    print(f"  제목: {course.get('TITLE', 'N/A')} [3]")
                    print(f"  훈련기관: {course.get('SUB_TITLE', 'N/A')} [3]")
                    print(f"  훈련 시작일: {course.get('TRA_START_DATE', 'N/A')} [3]")
                    print(f"  훈련 종료일: {course.get('TRA_END_DATE', 'N/A')} [3]")
                    print(f"  주소: {course.get('ADDRESS', 'N/A')} [3]")
                    print(f"  수강비: {course.get('COURSE_MAN', 'N/A')} [3]")
                    print(f"  실제 훈련비: {course.get('REAL_MAN', 'N/A')} [3]")
                    print(f"  취업률 (고용보험 3개월): {course.get('EI_EMPL_RATE3', 'N/A')}% [3]")
                    print(f"  만족도 점수: {course.get('STDG_SCOR', 'N/A')} [3]")
                    print("-" * 20)
            else:
                print("검색된 훈련과정이 없습니다.")
        else:
            print("API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.")
            print(data) # 전체 응답 출력하여 구조 확인
    elif params["returnType"] == "XML":
        # XML 응답을 처리할 경우
        root = ET.fromstring(response.text)
        print("\nAPI 호출 성공 (XML):")
        # XML 응답 구조에 따라 접근 [3]
        # 예시: 총 검색 건수
        scn_cnt = root.find('scn_cnt')
        if scn_cnt is not None:
            print(f"총 검색 건수: {scn_cnt.text}개 [3]")
        
        # 훈련과정 목록 (srchList/scn_list) 순회 [3]
        for course in root.findall('.//scn_list'):
            title = course.find('TITLE')
            if title is not None:
                print(f"  제목: {title.text} [3]")
            # 필요한 다른 항목들도 위와 같은 방식으로 접근하여 출력
            
    else:
        print(f"지원하지 않는 returnType: {params['returnType']}")

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP 오류 발생: {http_err}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"연결 오류 발생: {conn_err}")
except requests.exceptions.Timeout as timeout_err:
    print(f"타임아웃 오류 발생: {timeout_err}")
except requests.exceptions.RequestException as req_err:
    print(f"요청 오류 발생: {req_err}")
except json.JSONDecodeError as json_err:
    print(f"JSON 디코딩 오류: {json_err}. API 응답이 유효한 JSON 형식이 아닙니다.")
    print("응답 내용:", response.text[:500]) # 응답의 일부를 출력하여 문제 확인
except Exception as e:
    print(f"예상치 못한 오류 발생: {e}")
# Out:
# API 호출 중...
# {"srchList":[{"eiEmplCnt3Gt10":"","eiEmplRate6":"","eiEmplCnt3":"","eiEmplRate3":"","certificate":"","title":"당장 시작해야 하는 영업비밀과 지식재산권","realMan":"87780","telNo":"031-1644-9874","stdgScor":"0","traStartDate":"2025-01-01","grade":"","ncsCd":"05010201","regCourseMan":"0","trprDegr":"24","address":"경기 수원시 영통구","traEndDate":"2025-01-31","subTitle":"이룸캠퍼스","instCd":"201700192","trngAreaCd":"41117","trprId":"ACG20243000972854","yardMan":"1000","courseMan":"87780","trainTarget":"국민내일배움카드(일반)","trainTargetCd":"C0061","trainstCstId":"500020055230","contents":"","subTitleLink":"https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031","titleLink":"https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031","titleIcon":"<img src=\"hrd.work24.go.kr/images/ico_system13.gif\" alt=\"근로자직업능력개발훈련\" title=\"근로자직업능력개발훈련\" />"},{"eiEmplCnt3Gt10":"","eiEmplRate6":"","eiEmplCnt3":"","eiEmplRate3":"","certificate":"","title":"Good Morning, 행복한 병원을 위한 고객 만족 서비스 - 병원편","realMan":"92070","telNo":"02-6953-3893","stdgScor":"0","traStartDate":"2025-01-01","grade":"","ncsCd":"06010202","regCourseMan":"0","trprDegr":"229","address":"서울 강남구","traEndDate":"2025-01-30","subTitle":"윈스펙원격평생교육원","instCd":"201800831","trngAreaCd":"11680","trprId":"ACG20243001007020","yardMan":"500","courseMan":"92070","trainTarget":"국민내일배움카드(일반)","trainTargetCd":"C0061","trainstCstId":"500034225481","contents":"","subTitleLink":"https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031","titleLink":"https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031","titleIcon":"<img src=\"hrd.work24.go.kr/images/ico_system13.gif\" alt=\"근로자직업능력개발훈련\" title=\"근로자직업능력개발훈련\" />"},{"eiEmplCnt3Gt10":"","eiEmplRate6":"","eiEmplCnt3":"","eiEmplRate3":"","certificate":"","title":"보통 직장인을 위한 비즈니스 역량 18가지","realMan":"62370","telNo":"031-908-1448","stdgScor":"100.0","traStartDate":"2025-01-01","grade":"","ncsCd":"02010101","regCourseMan":"0","trprDegr":"282","address":"경기 고양시 일산동구","traEndDate":"2025-01-30","subTitle":"에듀퓨어","instCd":"200900603","trngAreaCd":"41285","trprId":"ACG20243000983095","yardMan":"150","courseMan":"62370","trainTarget":"국민내일배움카드(일반)","trainTargetCd":"C0061","trainstCstId":"500020034527","contents":"","subTitleLink":"https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031","titleLink":"https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031","titleIcon":"<img src=\"hrd.work24.go.kr/images/ico_system13.gif\" alt=\"근로자직업능력개발훈련\" title=\"근로자직업능력개발훈련\" />"},{"eiEmplCnt3Gt10":"","eiEmplRate6":"","eiEmplCnt3":"","eiEmplRate3":"","certificate":"","title":"[마케팅전문가양성코스] 마케팅 분석과 STP전략","realMan":"50490","telNo":"031-908-1448","stdgScor":"0","traStartDate":"2025-01-01","grade":"","ncsCd":"02010301","regCourseMan":"0","trprDegr":"245","address":"경기 고양시 일산동구","traEndDate":"2025-01-30","subTitle":"에듀퓨어","instCd":"200900603","trngAreaCd":"41285","trprId":"ACG20243001004178","yardMan":"150","courseMan":"50490","trainTarget":"국민내일배움카드(일반)","trainTargetCd":"C0061","trainstCstId":"500020034527","contents":"","subTitleLink":"https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&crseTracseSe=C0031","titleLink":"https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&crseTracseSe=C0031","titleIcon":"<img src=\"hrd.work24.go.kr/images/ico_system13.gif\" alt=\"근로자직업능력개발훈련\" title=\"근로자직업능력개발훈련\" />"},{"eiEmplCnt3Gt10":"","eiEmplRate6":"","eiEmplCnt3":"","eiEmplRate3":"","certific ...
#
# API 호출 성공 (JSON):
# {'srchList': [{'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '당장 시작해야 하는 영업비밀과 지식재산권', 'realMan': '87780', 'telNo': '031-1644-9874', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '05010201', 'regCourseMan': '0', 'trprDegr': '24', 'address': '경기 수원시 영통구', 'traEndDate': '2025-01-31', 'subTitle': '이룸캠퍼스', 'instCd': '201700192', 'trngAreaCd': '41117', 'trprId': 'ACG20243000972854', 'yardMan': '1000', 'courseMan': '87780', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020055230', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': 'Good Morning, 행복한 병원을 위한 고객 만족 서비스 - 병원편', 'realMan': '92070', 'telNo': '02-6953-3893', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '06010202', 'regCourseMan': '0', 'trprDegr': '229', 'address': '서울 강남구', 'traEndDate': '2025-01-30', 'subTitle': '윈스펙원격평생교육원', 'instCd': '201800831', 'trngAreaCd': '11680', 'trprId': 'ACG20243001007020', 'yardMan': '500', 'courseMan': '92070', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500034225481', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '보통 직장인을 위한 비즈니스 역량 18가지', 'realMan': '62370', 'telNo': '031-908-1448', 'stdgScor': '100.0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '02010101', 'regCourseMan': '0', 'trprDegr': '282', 'address': '경기 고양시 일산동구', 'traEndDate': '2025-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20243000983095', 'yardMan': '150', 'courseMan': '62370', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '[마케팅전문가양성코스] 마케팅 분석과 STP전략', 'realMan': '50490', 'telNo': '031-908-1448', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '02010301', 'regCourseMan': '0', 'trprDegr': '245', 'address': '경기 고양시 일산동구', 'traEndDate': '2025-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20243001004178', 'yardMan': '150', 'courseMan': '50490', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&cr ...
# API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.
# {'srchList': [{'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '당장 시작해야 하는 영업비밀과 지식재산권', 'realMan': '87780', 'telNo': '031-1644-9874', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '05010201', 'regCourseMan': '0', 'trprDegr': '24', 'address': '경기 수원시 영통구', 'traEndDate': '2025-01-31', 'subTitle': '이룸캠퍼스', 'instCd': '201700192', 'trngAreaCd': '41117', 'trprId': 'ACG20243000972854', 'yardMan': '1000', 'courseMan': '87780', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020055230', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000972854&tracseTme=24&trainstCstmrId=500020055230&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': 'Good Morning, 행복한 병원을 위한 고객 만족 서비스 - 병원편', 'realMan': '92070', 'telNo': '02-6953-3893', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '06010202', 'regCourseMan': '0', 'trprDegr': '229', 'address': '서울 강남구', 'traEndDate': '2025-01-30', 'subTitle': '윈스펙원격평생교육원', 'instCd': '201800831', 'trngAreaCd': '11680', 'trprId': 'ACG20243001007020', 'yardMan': '500', 'courseMan': '92070', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500034225481', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001007020&tracseTme=229&trainstCstmrId=500034225481&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '보통 직장인을 위한 비즈니스 역량 18가지', 'realMan': '62370', 'telNo': '031-908-1448', 'stdgScor': '100.0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '02010101', 'regCourseMan': '0', 'trprDegr': '282', 'address': '경기 고양시 일산동구', 'traEndDate': '2025-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20243000983095', 'yardMan': '150', 'courseMan': '62370', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243000983095&tracseTme=282&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleIcon': '<img src="hrd.work24.go.kr/images/ico_system13.gif" alt="근로자직업능력개발훈련" title="근로자직업능력개발훈련" />'}, {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '[마케팅전문가양성코스] 마케팅 분석과 STP전략', 'realMan': '50490', 'telNo': '031-908-1448', 'stdgScor': '0', 'traStartDate': '2025-01-01', 'grade': '', 'ncsCd': '02010301', 'regCourseMan': '0', 'trprDegr': '245', 'address': '경기 고양시 일산동구', 'traEndDate': '2025-01-30', 'subTitle': '에듀퓨어', 'instCd': '200900603', 'trngAreaCd': '41285', 'trprId': 'ACG20243001004178', 'yardMan': '150', 'courseMan': '50490', 'trainTarget': '국민내일배움카드(일반)', 'trainTargetCd': 'C0061', 'trainstCstId': '500020034527', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&crseTracseSe=C0031', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=ACG20243001004178&tracseTme=245&trainstCstmrId=500020034527&cr ...

# %%
import requests
import json
import xml.etree.ElementTree as ET # XML 응답을 처리할 경우 필요

# 1. API 기본 정보 설정
#BASE_URL = "https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 2. 필수 요청 Parameters 설정 [2]
# !!! [인증키] 부분은 반드시 본인이 발급받은 실제 인증키로 대체해야 합니다.
# 대괄호([])는 입력하지 않습니다.
params = {
    "authKey": "4a606afd-193d-4881-a83d-510c5d586276", # 4a606afd-193d-4881-a83d-510c5d586276
    "returnType": "JSON",  # XML 또는 JSON 선택. 여기서는 JSON으로 예시 [2]
    "outType": "1",        # '1': 리스트, '2': 상세 [2]
    "pageNum": "1",        # 시작 페이지 번호 (기본값 1, 최대 1000) [2]
    "pageSize": "100",      # 페이지당 출력 건수 (기본값 10, 최대 100) [2]
    "srchTraStDt": "20250101", # 훈련 시작일의 시작 범위 (YYYYMMDD 형식) [2]
    "srchTraEndDt": "20250716", # 훈련 시작일의 종료 범위 (YYYYMMDD 형식) [2]
    "sort": "ASC",         # 정렬 방법: "ASC" (오름차순), "DESC" (내림차순) [2]
    "sortCol": "2"         # 정렬 기준 컬럼: 1(훈련기관명), 2(훈련시작일), 3(취업률), 4(만족도점수) [2]
}

BASE_URL = f"https://www.work24.go.kr/cm/openApi/call/hr/callOpenApiSvcInfo310L01.do"
# 3. 선택 요청 Parameters 추가 [2]
# 예시: 훈련지역 대분류 '서울' (코드 '11') 및 훈련유형 'K-디지털 트레이닝' (코드 'C0104') 추가
# 여러 선택조건을 조합하여 사용할 수 있습니다.
optional_params = {
    "srchTraArea1": "11",   # 훈련지역 대분류: '11' 서울 [2]
    "crseTracseSe": "C0104" # 훈련유형: 'C0104' K-디지털 트레이닝 [2]
    # "srchNcs1": "20",       # NCS 직종 1차분류 코드: '20' 정보통신 [2]
    # "srchTraProcessNm": "파이썬", # 훈련과정명 검색 [2]
}

# 필수 및 선택 Parameters를 병합
params.update(optional_params)

# 4. API 호출
print("API 호출 중...")
try:
    response = requests.get(BASE_URL, params=params)
    response.raise_for_status() # HTTP 에러가 발생하면 예외를 발생시킵니다.

    # 5. 응답 데이터 처리
    if params["returnType"] == "JSON":
        data = response.json()
        print("\nAPI 호출 성공 (JSON):")
        print(type(data), data.keys())
        # JSON 데이터 구조에 따라 접근
        if data and 'srchList' in data:
            # 검색된 총 건수, 현재 페이지, 페이지당 출력 개수 정보 [3]
            total_count = data.get('scn_cnt', 'N/A')
            current_page = data.get('pageNum', 'N/A')
            page_size = data.get('pageSize', 'N/A')

            print(f"총 검색 건수: {total_count}개 [3]")
            print(f"현재 페이지: {current_page}, 페이지당 출력 개수: {page_size}개 [3]")
            print('---------------------------------------------------------')
            print(type(data['srchList']), data['srchList'][0], len( data['srchList']))

            # 훈련과정 목록 출력 [3]
            training_list = data['srchList']
            if not isinstance(training_list, list): # 단일 항목일 경우 리스트가 아닌 딕셔너리로 올 수 있음
                training_list = [training_list]

            if training_list:
                print("\n검색된 훈련과정 목록:")
                for i, course in enumerate(training_list):
                    print(f"--- 훈련과정 {i+1} ---")
                    print(f"  제목: {course.get('title', 'N/A')} [3]")
                    print(f"  훈련기관: {course.get('subTitle', 'N/A')} [3]")
                    print(f"  훈련 시작일: {course.get('traStartDate', 'N/A')} [3]")
                    print(f"  훈련 종료일: {course.get('traEndDate', 'N/A')} [3]")
                    print(f"  주소: {course.get('address', 'N/A')} [3]")
                    print(f"  수강비: {course.get('courseMan', 'N/A')} [3]")
                    print(f"  실제 훈련비: {course.get('realMan', 'N/A')} [3]")
                    print(f"  취업률 (고용보험 3개월): {course.get('eIEmplRate3', 'N/A')}% [3]")
                    print(f"  만족도 점수: {course.get('stdgScor', 'N/A')} [3]")
                    print("-" * 20)
            else:
                print("검색된 훈련과정이 없습니다.")
        else:
            print("API 응답에서 'HRDNet' 또는 'srchList'를 찾을 수 없습니다. 응답 구조를 확인하세요.")
            print(data) # 전체 응답 출력하여 구조 확인
    elif params["returnType"] == "XML":
        # XML 응답을 처리할 경우
        root = ET.fromstring(response.text)
        print("\nAPI 호출 성공 (XML):")
        # XML 응답 구조에 따라 접근 [3]
        # 예시: 총 검색 건수
        scn_cnt = root.find('scn_cnt')
        if scn_cnt is not None:
            print(f"총 검색 건수: {scn_cnt.text}개 [3]")
        
        # 훈련과정 목록 (srchList/scn_list) 순회 [3]
        for course in root.findall('.//scn_list'):
            title = course.find('TITLE')
            if title is not None:
                print(f"  제목: {title.text} [3]")
            # 필요한 다른 항목들도 위와 같은 방식으로 접근하여 출력
            
    else:
        print(f"지원하지 않는 returnType: {params['returnType']}")

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP 오류 발생: {http_err}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"연결 오류 발생: {conn_err}")
except requests.exceptions.Timeout as timeout_err:
    print(f"타임아웃 오류 발생: {timeout_err}")
except requests.exceptions.RequestException as req_err:
    print(f"요청 오류 발생: {req_err}")
except json.JSONDecodeError as json_err:
    print(f"JSON 디코딩 오류: {json_err}. API 응답이 유효한 JSON 형식이 아닙니다.")
    print("응답 내용:", response.text[:500]) # 응답의 일부를 출력하여 문제 확인
except Exception as e:
    print(f"예상치 못한 오류 발생: {e}")
# Out:
# API 호출 중...
#
# API 호출 성공 (JSON):
# <class 'dict'> dict_keys(['srchList', 'scn_cnt', 'pageSize', 'pageNum'])
# 총 검색 건수: 658개 [3]
# 현재 페이지: 1, 페이지당 출력 개수: 100개 [3]
# ---------------------------------------------------------
# <class 'list'> {'eiEmplCnt3Gt10': '', 'eiEmplRate6': '', 'eiEmplCnt3': '', 'eiEmplRate3': '', 'certificate': '', 'title': '자바 스프링 리액트로 완성하는 클라우드 활용 풀스택 개발 ', 'realMan': '9477000', 'telNo': '02-855-9611', 'stdgScor': '92.2', 'traStartDate': '2025-01-02', 'grade': '', 'ncsCd': '20010202', 'regCourseMan': '19', 'trprDegr': '16', 'address': '서울 관악구', 'traEndDate': '2025-09-25', 'subTitle': '한국정보교육원(구.경원직업전문학교)', 'instCd': '200400659', 'trngAreaCd': '11350', 'trprId': 'AIG20230000412579', 'yardMan': '25', 'courseMan': '9477000', 'trainTarget': 'K-디지털 트레이닝', 'trainTargetCd': 'C0104', 'trainstCstId': '500020031803', 'contents': '', 'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412579&tracseTme=16&trainstCstmrId=500020031803&crseTracseSe=C0061', 'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412579&tracseTme=16&trainstCstmrId=500020031803&crseTracseSe=C0061', 'titleIcon': ''} 100
#
# 검색된 훈련과정 목록:
# --- 훈련과정 1 ---
#   제목: 자바 스프링 리액트로 완성하는 클라우드 활용 풀스택 개발  [3]
#   훈련기관: 한국정보교육원(구.경원직업전문학교) [3]
#   훈련 시작일: 2025-01-02 [3]
#   훈련 종료일: 2025-09-25 [3]
#   주소: 서울 관악구 [3]
#   수강비: 9477000 [3]
#   실제 훈련비: 9477000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 92.2 [3]
# --------------------
# --- 훈련과정 2 ---
#   제목: Tech 우수 인재를 위한 풀스택 과정, 한국경제신문 with toss bank (ML Ops 합동 프로젝트) [3]
#   훈련기관: 한경아카데미 [3]
#   훈련 시작일: 2025-01-02 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 77.8 [3]
# --------------------
# --- 훈련과정 3 ---
#   제목: Tech 우수 인재를 위한 ML Ops 과정, 한국경제신문 with toss bank (풀스택 합동 프로젝트) [3]
#   훈련기관: 한경아카데미 [3]
#   훈련 시작일: 2025-01-02 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.2 [3]
# --------------------
# --- 훈련과정 4 ---
#   제목: [KG ICT] 청년 AI 로보틱스 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17569200 [3]
#   실제 훈련비: 17569200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 65.1 [3]
# --------------------
# --- 훈련과정 5 ---
#   제목: [KG ICT] 청년 AI 로보틱스 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17569200 [3]
#   실제 훈련비: 17569200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 65.1 [3]
# --------------------
# --- 훈련과정 6 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 7 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 8 ---
#   제목: JAVA 기반 백엔드 개발자 양성 [3]
#   훈련기관: (주)신세계아이앤씨 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-09 [3]
#   주소: 서울 강남구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.6 [3]
# --------------------
# --- 훈련과정 9 ---
#   제목: [KG ICT] 청년 AI 로보틱스 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17569200 [3]
#   실제 훈련비: 17569200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 65.1 [3]
# --------------------
# --- 훈련과정 10 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 11 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 12 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 13 ---
#   제목: 빅데이터 기반 컴퓨터비전(CV) 데이터사이언스 과정 [3]
#   훈련기관: 메디치교육센터 평생교육시설 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-09 [3]
#   주소: 서울 금천구 [3]
#   수강비: 8999360 [3]
#   실제 훈련비: 8999360 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 81.0 [3]
# --------------------
# --- 훈련과정 14 ---
#   제목: [KG ICT] 청년 AI 로보틱스 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-02 [3]
#   주소: 서울 중구 [3]
#   수강비: 17569200 [3]
#   실제 훈련비: 17569200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 65.1 [3]
# --------------------
# --- 훈련과정 15 ---
#   제목: [두산로보틱스] 지능형 로보틱스 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-06 [3]
#   훈련 종료일: 2025-07-05 [3]
#   주소: 서울 중구 [3]
#   수강비: 15336750 [3]
#   실제 훈련비: 15336750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 16 ---
#   제목: SK네트웍스 Family AI 캠프 [3]
#   훈련기관: 플레이데이터평생교육원 [3]
#   훈련 시작일: 2025-01-07 [3]
#   훈련 종료일: 2025-07-07 [3]
#   주소: 서울 서초구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 80.4 [3]
# --------------------
# --- 훈련과정 17 ---
#   제목: ChatGPT를 활용한 AI 웹앱(자바,파이썬) 서비스 개발자 양성 과정 [3]
#   훈련기관: 글로벌아이티(IT)인재개발학원 [3]
#   훈련 시작일: 2025-01-07 [3]
#   훈련 종료일: 2025-07-09 [3]
#   주소: 서울 관악구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 87.3 [3]
# --------------------
# --- 훈련과정 18 ---
#   제목: 자바(JAVA) 웹개발자 양성과정(클라우드) [3]
#   훈련기관: 에이콘아카데미 홍대학원 [3]
#   훈련 시작일: 2025-01-07 [3]
#   훈련 종료일: 2025-07-11 [3]
#   주소: 서울 마포구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 89.8 [3]
# --------------------
# --- 훈련과정 19 ---
#   제목: 클라우드기반 스마트 융합보안 과정 [3]
#   훈련기관: 인포섹 아카데미 [3]
#   훈련 시작일: 2025-01-07 [3]
#   훈련 종료일: 2025-07-24 [3]
#   주소: 경기 성남시 분당구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 20 ---
#   제목: 클라우드 기반의 자바 풀스택 (Springboot, React, flutter) 개발자 [3]
#   훈련기관: 하이미디어아카데미 [3]
#   훈련 시작일: 2025-01-08 [3]
#   훈련 종료일: 2025-07-03 [3]
#   주소: 서울 서초구 [3]
#   수강비: 9097920 [3]
#   실제 훈련비: 9097920 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 93.7 [3]
# --------------------
# --- 훈련과정 21 ---
#   제목: 심화_ROS2와 AI를 활용한 자율주행&로봇팔 개발자 부트캠프 [3]
#   훈련기관: 애드인에듀 아카데미 구로가산센터 [3]
#   훈련 시작일: 2025-01-13 [3]
#   훈련 종료일: 2025-03-19 [3]
#   주소: 서울 금천구 [3]
#   수강비: 5123320 [3]
#   실제 훈련비: 5123320 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 89.7 [3]
# --------------------
# --- 훈련과정 22 ---
#   제목: AWS와 Docker & Kubernetes를 활용한 Java Full-Stack 개발자 양성과정 [3]
#   훈련기관: 쌍용교육센터 [3]
#   훈련 시작일: 2025-01-13 [3]
#   훈련 종료일: 2025-07-29 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9856080 [3]
#   실제 훈련비: 9856080 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 95.1 [3]
# --------------------
# --- 훈련과정 23 ---
#   제목: HIWARE로 완성하는 클라우드 IT 인프라 보안 엔지니어 양성 [3]
#   훈련기관: 한국정보교육원(구.경원직업전문학교) [3]
#   훈련 시작일: 2025-01-13 [3]
#   훈련 종료일: 2025-07-10 [3]
#   주소: 서울 관악구 [3]
#   수강비: 9097920 [3]
#   실제 훈련비: 9097920 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 88.4 [3]
# --------------------
# --- 훈련과정 24 ---
#   제목: Cisco VirtuNet Cloud 통합 구현 [3]
#   훈련기관: 한국표준협회 [3]
#   훈련 시작일: 2025-01-14 [3]
#   훈련 종료일: 2025-07-22 [3]
#   주소: 서울 강남구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 90.6 [3]
# --------------------
# --- 훈련과정 25 ---
#   제목: 챗GPT를 활용한 자바(JAVA) 스프링 및 데이터 분석 시스템기반 웹 플랫폼 구축 과정 [3]
#   훈련기관: 솔데스크강남학원 [3]
#   훈련 시작일: 2025-01-14 [3]
#   훈련 종료일: 2025-08-29 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9872720 [3]
#   실제 훈련비: 9872720 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 96.6 [3]
# --------------------
# --- 훈련과정 26 ---
#   제목: 프로그래머스 데브코스: 생성형 AI활용 백엔드 개발 [3]
#   훈련기관: (주)그렙 [3]
#   훈련 시작일: 2025-01-15 [3]
#   훈련 종료일: 2025-07-18 [3]
#   주소: 서울 서초구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 27 ---
#   제목: 콘텐츠 융합을 위한 자바(JAVA)기반  Full Stack 개발자 양성과정 [3]
#   훈련기관: 에이콘아카데미(강남) [3]
#   훈련 시작일: 2025-01-15 [3]
#   훈련 종료일: 2025-07-10 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9097920 [3]
#   실제 훈련비: 9097920 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 86.2 [3]
# --------------------
# --- 훈련과정 28 ---
#   제목: 프로젝트 기반 풀스택(프론트/백엔드) 개발자 취업캠프(리액트,자바,스프링부트) [3]
#   훈련기관: 더조은컴퓨터아카데미 종로 [3]
#   훈련 시작일: 2025-01-15 [3]
#   훈련 종료일: 2025-09-01 [3]
#   주소: 서울 종로구 [3]
#   수강비: 11448550 [3]
#   실제 훈련비: 11448550 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 98.2 [3]
# --------------------
# --- 훈련과정 29 ---
#   제목: 심화_프론트엔드 엔지니어 부트캠프 [3]
#   훈련기관: 코드잇 평생교육원 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-03-18 [3]
#   주소: 서울 강남구 [3]
#   수강비: 5097490 [3]
#   실제 훈련비: 5097490 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.5 [3]
# --------------------
# --- 훈련과정 30 ---
#   제목: 클라우드 기반 풀스택 엔지니어 부트캠프 [3]
#   훈련기관: 코드잇 평생교육원 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-08-19 [3]
#   주소: 서울 강남구 [3]
#   수강비: 22687500 [3]
#   실제 훈련비: 22687500 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.3 [3]
# --------------------
# --- 훈련과정 31 ---
#   제목: 클라우드 가상화 기반 자바(JAVA) 개발자 양성과정 [3]
#   훈련기관: 아이티윌 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-07-15 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9173730 [3]
#   실제 훈련비: 9173730 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 86.2 [3]
# --------------------
# --- 훈련과정 32 ---
#   제목: MSA기반 자바 백엔드 개발자 양성과정 [3]
#   훈련기관: 아이티윌 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-07-22 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9189220 [3]
#   실제 훈련비: 9189220 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 71.4 [3]
# --------------------
# --- 훈련과정 33 ---
#   제목: 클라우드 기반 Node.js 백엔드 엔지니어 부트캠프 [3]
#   훈련기관: 코드잇 평생교육원 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-08-18 [3]
#   주소: 서울 강남구 [3]
#   수강비: 22687500 [3]
#   실제 훈련비: 22687500 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 34 ---
#   제목: 융합_빅데이터를 활용한 디지털금융 전문가 [3]
#   훈련기관: 유비온디지털교육센터 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-07-09 [3]
#   주소: 서울 구로구 [3]
#   수강비: 16298700 [3]
#   실제 훈련비: 16298700 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 78.6 [3]
# --------------------
# --- 훈련과정 35 ---
#   제목: AI 활용 데이터 분석가 부트캠프 [3]
#   훈련기관: 코드잇 평생교육원 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-08-14 [3]
#   주소: 서울 강남구 [3]
#   수강비: 22687500 [3]
#   실제 훈련비: 22687500 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 86.0 [3]
# --------------------
# --- 훈련과정 36 ---
#   제목: IaC 기반 하이브리드 클라우드 인프라 및 보안 솔루션 구축 과정 [3]
#   훈련기관: 메가스터디아이티(IT)아카데미학원 [3]
#   훈련 시작일: 2025-01-16 [3]
#   훈련 종료일: 2025-07-21 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9189220 [3]
#   실제 훈련비: 9189220 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 37 ---
#   제목: VR을 활용한 실감형 콘텐츠 제작자 양성과정 [3]
#   훈련기관: 엠비씨(MBC)아카데미 컴퓨터교육센터 화곡점 [3]
#   훈련 시작일: 2025-01-17 [3]
#   훈련 종료일: 2025-07-15 [3]
#   주소: 서울 강서구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 61.9 [3]
# --------------------
# --- 훈련과정 38 ---
#   제목: [기업프로젝트] 메타버스 게임 개발자 양성 [3]
#   훈련기관: 주식회사경일게임아이티아카데미 [3]
#   훈련 시작일: 2025-01-17 [3]
#   훈련 종료일: 2025-08-14 [3]
#   주소: 서울 강동구 [3]
#   수강비: 10632160 [3]
#   실제 훈련비: 10632160 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 39 ---
#   제목: 융합_프로젝트 기반 에듀테크 기획자 [3]
#   훈련기관: 유비온디지털교육센터 [3]
#   훈련 시작일: 2025-01-17 [3]
#   훈련 종료일: 2025-06-13 [3]
#   주소: 서울 구로구 [3]
#   수강비: 7081770 [3]
#   실제 훈련비: 7081770 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 71.4 [3]
# --------------------
# --- 훈련과정 40 ---
#   제목: 엘리스 QA 자동화 엔지니어 트랙 [3]
#   훈련기관: (주)엘리스그룹 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-05-20 [3]
#   주소: 서울 강남구 [3]
#   수강비: 11979000 [3]
#   실제 훈련비: 11979000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 63.5 [3]
# --------------------
# --- 훈련과정 41 ---
#   제목: 백엔드 개발자 부트캠프(스프링) [3]
#   훈련기관: 멀티캠퍼스 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-06-17 [3]
#   주소: 서울 강남구 [3]
#   수강비: 14229600 [3]
#   실제 훈련비: 14229600 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 91.0 [3]
# --------------------
# --- 훈련과정 42 ---
#   제목: [LG유플러스] 유레카 백엔드 개발자 [3]
#   훈련기관: 멀티캠퍼스 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-08-12 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 89.8 [3]
# --------------------
# --- 훈련과정 43 ---
#   제목: [LG유플러스] 유레카 프론트엔드 개발자 [3]
#   훈련기관: 멀티캠퍼스 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-08-12 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 75.4 [3]
# --------------------
# --- 훈련과정 44 ---
#   제목: AI MSP 베스핀글로벌의 멀티클라우드(AWS·Azure·GCP·NCP) 엔지니어 부트캠프 [3]
#   훈련기관: 베스핀글로벌주식회사 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-07-30 [3]
#   주소: 서울 서초구 [3]
#   수강비: 18150000 [3]
#   실제 훈련비: 18150000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 45 ---
#   제목: [스타트업][스마트훈련]실무형 UX/UI 디자이너 양성과정 [3]
#   훈련기관: 팀스파르타주식회사 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-05-30 [3]
#   주소: 서울 강남구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 82.2 [3]
# --------------------
# --- 훈련과정 46 ---
#   제목: [Unity] 유니티 부트캠프 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-07-21 [3]
#   주소: 서울 중구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 70.6 [3]
# --------------------
# --- 훈련과정 47 ---
#   제목: [LG유플러스] 유레카 백엔드 개발자 [3]
#   훈련기관: 멀티캠퍼스 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-08-12 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 89.8 [3]
# --------------------
# --- 훈련과정 48 ---
#   제목: [LG유플러스] 유레카 프론트엔드 개발자 [3]
#   훈련기관: 멀티캠퍼스 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-08-12 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 75.4 [3]
# --------------------
# --- 훈련과정 49 ---
#   제목: 인공지능(AI)활용 서비스 개발자(프론트엔드_React) 취업과정 [3]
#   훈련기관: 더조은컴퓨터아카데미 종로 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-07-31 [3]
#   주소: 서울 종로구 [3]
#   수강비: 9872720 [3]
#   실제 훈련비: 9872720 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 50 ---
#   제목: 실무형 Unity 게임개발자 양성과정 [3]
#   훈련기관: 팀스파르타주식회사 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-06-02 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 87.3 [3]
# --------------------
# --- 훈련과정 51 ---
#   제목: Public Cloud 활용 자바(JAVA) 웹 애플리케이션(Spring, Docker) 개발자 양성과정 [3]
#   훈련기관: 중앙HTA IT교육원 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-08-14 [3]
#   주소: 서울 종로구 [3]
#   수강비: 10235160 [3]
#   실제 훈련비: 10235160 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 80.4 [3]
# --------------------
# --- 훈련과정 52 ---
#   제목: AI와 VR을 활용한 메타버스 건축 모델링 제작자 양성 [3]
#   훈련기관: 엠비씨(MBC)아카데미 컴퓨터교육센터 화곡점 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-07-23 [3]
#   주소: 서울 강서구 [3]
#   수강비: 9379080 [3]
#   실제 훈련비: 9379080 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 53 ---
#   제목: 실무형 Unity 게임개발자 양성과정 [3]
#   훈련기관: 팀스파르타주식회사 [3]
#   훈련 시작일: 2025-01-20 [3]
#   훈련 종료일: 2025-06-02 [3]
#   주소: 서울 강남구 [3]
#   수강비: 19602000 [3]
#   실제 훈련비: 19602000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 87.3 [3]
# --------------------
# --- 훈련과정 54 ---
#   제목: 스타트업 맞춤형 프로덕트 디자이너 양성 과정 [3]
#   훈련기관: 넥스트러너스평생교육시설 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-06-09 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13068000 [3]
#   실제 훈련비: 13068000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 71.9 [3]
# --------------------
# --- 훈련과정 55 ---
#   제목: 타입스크립트로 함께하는 웹 풀 사이클 개발(React, Node.js) [3]
#   훈련기관: (주)그렙 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-07-21 [3]
#   주소: 서울 서초구 [3]
#   수강비: 15881250 [3]
#   실제 훈련비: 15881250 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 70.9 [3]
# --------------------
# --- 훈련과정 56 ---
#   제목: LG U+ Why Not SW캠프 [3]
#   훈련기관: 현대경제연구원 인재개발원 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-08-02 [3]
#   주소: 경기 용인시 기흥구 [3]
#   수강비: 18876000 [3]
#   실제 훈련비: 18876000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 79.9 [3]
# --------------------
# --- 훈련과정 57 ---
#   제목: 재직자_[아이펠]서비스 개발자를 위한 LLM 역량 강화 과정 [3]
#   훈련기관: (주)모두의연구소 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-04-19 [3]
#   주소: 서울 강남구 [3]
#   수강비: 3702600 [3]
#   실제 훈련비: 3702600 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 88.2 [3]
# --------------------
# --- 훈련과정 58 ---
#   제목: 한화시스템 BEYOND SW 캠프 - “청년들의 미래를 이끄는 프로그램” [3]
#   훈련기관: 플레이데이터평생교육원 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-07-21 [3]
#   주소: 서울 서초구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 89.2 [3]
# --------------------
# --- 훈련과정 59 ---
#   제목: [삼정] ESG 데이터 활용 풀스택 개발자 과정 [3]
#   훈련기관: 삼정회계법인 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-07-31 [3]
#   주소: 서울 강남구 [3]
#   수강비: 18876000 [3]
#   실제 훈련비: 18876000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 60 ---
#   제목: 데이터분석 데브코스 [3]
#   훈련기관: (주)그렙 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-05-14 [3]
#   주소: 서울 서초구 [3]
#   수강비: 10236600 [3]
#   실제 훈련비: 10236600 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 80.6 [3]
# --------------------
# --- 훈련과정 61 ---
#   제목: 자바(JAVA)와 사물인터넷(IOT)을 활용한 하이브리드 웹앱 풀스택 과정 [3]
#   훈련기관: 솔데스크강남학원 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-08-19 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9872720 [3]
#   실제 훈련비: 9872720 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 97.9 [3]
# --------------------
# --- 훈련과정 62 ---
#   제목: 무중단 서비스를 위한 클라우드기반 AI활용 자바풀스택 개발자 과정 [3]
#   훈련기관: 한국ICT인재개발원 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-08-06 [3]
#   주소: 서울 마포구 [3]
#   수강비: 10252440 [3]
#   실제 훈련비: 10252440 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 94.6 [3]
# --------------------
# --- 훈련과정 63 ---
#   제목: 자율비행 드론 설계 및 제작(솔리드웍스,카티아,3D프린터,제어) [3]
#   훈련기관: 글로벌산업기술교육원 [3]
#   훈련 시작일: 2025-01-21 [3]
#   훈련 종료일: 2025-07-25 [3]
#   주소: 서울 금천구 [3]
#   수강비: 18150000 [3]
#   실제 훈련비: 18150000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 98.8 [3]
# --------------------
# --- 훈련과정 64 ---
#   제목: 클라우드기반 AI 대화형 서비스 웹개발자 양성 [3]
#   훈련기관: 한국ICT인재개발원 [3]
#   훈련 시작일: 2025-01-22 [3]
#   훈련 종료일: 2025-08-04 [3]
#   주소: 서울 마포구 [3]
#   수강비: 10007710 [3]
#   실제 훈련비: 10007710 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 93.5 [3]
# --------------------
# --- 훈련과정 65 ---
#   제목: 클라우드환경 자바(JAVA) 풀스택 AI융합 웹개발자(AWS, SpringBoot, React.js) [3]
#   훈련기관: 하이미디어컴퓨터학원 [3]
#   훈련 시작일: 2025-01-22 [3]
#   훈련 종료일: 2025-08-07 [3]
#   주소: 서울 구로구 [3]
#   수강비: 10100550 [3]
#   실제 훈련비: 10100550 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 66 ---
#   제목: [이스트캠프] iOS 앱 개발 실전 과정(SwiftUI, UIKit) [3]
#   훈련기관: (주)이스트소프트 [3]
#   훈련 시작일: 2025-01-22 [3]
#   훈련 종료일: 2025-06-16 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13213200 [3]
#   실제 훈련비: 13213200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 73.8 [3]
# --------------------
# --- 훈련과정 67 ---
#   제목: JAVA 기반 백엔드 개발자 양성 [3]
#   훈련기관: (주)신세계아이앤씨 [3]
#   훈련 시작일: 2025-01-23 [3]
#   훈련 종료일: 2025-07-29 [3]
#   주소: 서울 강남구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.6 [3]
# --------------------
# --- 훈련과정 68 ---
#   제목: 보안 위협 대응을 위한 클라우드 기반 보안 엔지니어 양성 과정 [3]
#   훈련기관: 케이지에듀원아이티뱅크노량진학원 [3]
#   훈련 시작일: 2025-01-23 [3]
#   훈련 종료일: 2025-07-31 [3]
#   주소: 서울 동작구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 69 ---
#   제목: [삼정] ESG 데이터 기반 재무영향 자동화 개발자 과정 [3]
#   훈련기관: 삼정회계법인 [3]
#   훈련 시작일: 2025-01-24 [3]
#   훈련 종료일: 2025-07-30 [3]
#   주소: 서울 강남구 [3]
#   수강비: 18150000 [3]
#   실제 훈련비: 18150000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 70 ---
#   제목: [이스트캠프]오르미 백엔드 개발(Java, Spring, JPA) [3]
#   훈련기관: (주)이스트소프트 [3]
#   훈련 시작일: 2025-01-27 [3]
#   훈련 종료일: 2025-06-17 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13213200 [3]
#   실제 훈련비: 13213200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 83.3 [3]
# --------------------
# --- 훈련과정 71 ---
#   제목: [이스트캠프] 와썹 AI 서비스 기획(PM, UI/UX, BM) [3]
#   훈련기관: (주)이스트소프트 [3]
#   훈련 시작일: 2025-01-27 [3]
#   훈련 종료일: 2025-06-18 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13213200 [3]
#   실제 훈련비: 13213200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 86.5 [3]
# --------------------
# --- 훈련과정 72 ---
#   제목: 데이터 중심 그로스 마케팅 과정 [3]
#   훈련기관: 주식회사멋쟁이사자처럼 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-05-23 [3]
#   주소: 서울 종로구 [3]
#   수강비: 11035200 [3]
#   실제 훈련비: 11035200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 76.3 [3]
# --------------------
# --- 훈련과정 73 ---
#   제목: 엘리스 AI 사업개발자 트랙 [3]
#   훈련기관: (주)엘리스그룹 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-05-28 [3]
#   주소: 서울 강남구 [3]
#   수강비: 12432750 [3]
#   실제 훈련비: 12432750 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 28.6 [3]
# --------------------
# --- 훈련과정 74 ---
#   제목: [프로젝트] 클라우드(AWS)활용 자바/스프링 개발 부트캠프 [3]
#   훈련기관: 구디아카데미 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-08-14 [3]
#   주소: 서울 금천구 [3]
#   수강비: 9872720 [3]
#   실제 훈련비: 9872720 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 95.2 [3]
# --------------------
# --- 훈련과정 75 ---
#   제목: [정보보안] 취약점분석 등 정보보안 전문가 취업캠프 [3]
#   훈련기관: 더조은컴퓨터아카데미 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-08-14 [3]
#   주소: 서울 강남구 [3]
#   수강비: 10043590 [3]
#   실제 훈련비: 10043590 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 76 ---
#   제목: 프로젝트 기반의 프론트앤드 개발자 양성(with 생성형 AI) [3]
#   훈련기관: 대우능력개발원 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-07-31 [3]
#   주소: 서울 중랑구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 77 ---
#   제목: [로켓 부스트캠프] 블록체인 엔지니어 부트캠프 [3]
#   훈련기관: 주식회사 로켓부스트 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-08-26 [3]
#   주소: 서울 성동구 [3]
#   수강비: 20328000 [3]
#   실제 훈련비: 20328000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 78 ---
#   제목: [한글과컴퓨터] Hancom AI Academy [3]
#   훈련기관: 한국생산성본부 [3]
#   훈련 시작일: 2025-01-31 [3]
#   훈련 종료일: 2025-07-25 [3]
#   주소: 서울 종로구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 79 ---
#   제목: [이스트캠프] 와썹 AI 모델 개발(Python, 인공지능, 딥러닝) [3]
#   훈련기관: (주)이스트소프트 [3]
#   훈련 시작일: 2025-02-03 [3]
#   훈련 종료일: 2025-06-18 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13213200 [3]
#   실제 훈련비: 13213200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 79.4 [3]
# --------------------
# --- 훈련과정 80 ---
#   제목: 심화_AI를 활용한 백엔드 아키텍처 심화 과정 [3]
#   훈련기관: 팀스파르타주식회사 [3]
#   훈련 시작일: 2025-02-03 [3]
#   훈련 종료일: 2025-05-09 [3]
#   주소: 서울 강남구 [3]
#   수강비: 5097490 [3]
#   실제 훈련비: 5097490 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 88.6 [3]
# --------------------
# --- 훈련과정 81 ---
#   제목: AWS와 Docker & Kubernetes를 활용한 Java Full-Stack 개발자 양성과정 [3]
#   훈련기관: 쌍용교육센터 [3]
#   훈련 시작일: 2025-02-03 [3]
#   훈련 종료일: 2025-08-12 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9856080 [3]
#   실제 훈련비: 9856080 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 95.1 [3]
# --------------------
# --- 훈련과정 82 ---
#   제목: [HARMAN] 세미콘아카데미-시스템반도체 설계/검증 엔지니어 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-02-04 [3]
#   훈련 종료일: 2025-08-26 [3]
#   주소: 서울 중구 [3]
#   수강비: 17242500 [3]
#   실제 훈련비: 17242500 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 83 ---
#   제목: 실무 데이터 기반 반도체 소자/공정 엔지니어 융합과정 [3]
#   훈련기관: 렛유인에듀이공계핵심인재양성평생교육원 [3]
#   훈련 시작일: 2025-02-04 [3]
#   훈련 종료일: 2025-05-21 [3]
#   주소: 서울 강남구 [3]
#   수강비: 4459910 [3]
#   실제 훈련비: 4459910 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 92.5 [3]
# --------------------
# --- 훈련과정 84 ---
#   제목: AWS와 Azure 기반 하이브리드 멀티클라우드 DevOps [3]
#   훈련기관: (주)솔데스크 [3]
#   훈련 시작일: 2025-02-04 [3]
#   훈련 종료일: 2025-07-30 [3]
#   주소: 서울 종로구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 83.1 [3]
# --------------------
# --- 훈련과정 85 ---
#   제목: [가비아] g클라우드 기반의 그룹웨어 개발자 양성과정 [3]
#   훈련기관: 한국표준협회 [3]
#   훈련 시작일: 2025-02-04 [3]
#   훈련 종료일: 2025-08-08 [3]
#   주소: 서울 강남구 [3]
#   수강비: 18150000 [3]
#   실제 훈련비: 18150000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 86 ---
#   제목: AI/빅데이터를 활용한 사이버보안 위협 탐지기술 개발자 양성과정 [3]
#   훈련기관: 한국표준협회 [3]
#   훈련 시작일: 2025-02-05 [3]
#   훈련 종료일: 2025-07-07 [3]
#   주소: 서울 강남구 [3]
#   수강비: 14520000 [3]
#   실제 훈련비: 14520000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 79.4 [3]
# --------------------
# --- 훈련과정 87 ---
#   제목: 웹 서비스 프로젝트 기반 프론트엔드 엔지니어 부트캠프 [3]
#   훈련기관: 주식회사멋쟁이사자처럼 [3]
#   훈련 시작일: 2025-02-05 [3]
#   훈련 종료일: 2025-08-08 [3]
#   주소: 서울 종로구 [3]
#   수강비: 16698000 [3]
#   실제 훈련비: 16698000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 91.1 [3]
# --------------------
# --- 훈련과정 88 ---
#   제목: 클라우드 데브옵스 프론트엔드&백엔드 자바(JAVA) 풀스택 개발자 취업캠프 [3]
#   훈련기관: 중앙정보기술인재개발원 [3]
#   훈련 시작일: 2025-02-05 [3]
#   훈련 종료일: 2025-07-29 [3]
#   주소: 서울 강남구 [3]
#   수강비: 9097920 [3]
#   실제 훈련비: 9097920 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 90.9 [3]
# --------------------
# --- 훈련과정 89 ---
#   제목: (현대로템) K-방산 AI모델 개발과정 [3]
#   훈련기관: 한국전파진흥협회 [3]
#   훈련 시작일: 2025-02-05 [3]
#   훈련 종료일: 2025-07-24 [3]
#   주소: 서울 양천구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 71.1 [3]
# --------------------
# --- 훈련과정 90 ---
#   제목: 카티아 로보틱스 설계와 유니티 스마트팩토리 가상구현 [3]
#   훈련기관: 코드랩아카데미학원 [3]
#   훈련 시작일: 2025-02-06 [3]
#   훈련 종료일: 2025-08-06 [3]
#   주소: 서울 금천구 [3]
#   수강비: 12210000 [3]
#   실제 훈련비: 12210000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 91.8 [3]
# --------------------
# --- 훈련과정 91 ---
#   제목: [부트캠프]AI 인공지능 웹서비스 풀스택 개발자(AICC딥러닝) [3]
#   훈련기관: 코드랩아카데미학원 [3]
#   훈련 시작일: 2025-02-06 [3]
#   훈련 종료일: 2025-08-05 [3]
#   주소: 서울 금천구 [3]
#   수강비: 12210000 [3]
#   실제 훈련비: 12210000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 83.4 [3]
# --------------------
# --- 훈련과정 92 ---
#   제목: SK네트웍스 Family AI 캠프 [3]
#   훈련기관: 플레이데이터평생교육원 [3]
#   훈련 시작일: 2025-02-07 [3]
#   훈련 종료일: 2025-08-01 [3]
#   주소: 서울 서초구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 80.4 [3]
# --------------------
# --- 훈련과정 93 ---
#   제목: 바이오헬스 실무 전문과정 [3]
#   훈련기관: 건국대학교산학협력단 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-07-11 [3]
#   주소: 서울 광진구 [3]
#   수강비: 11470800 [3]
#   실제 훈련비: 11470800 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 66.3 [3]
# --------------------
# --- 훈련과정 94 ---
#   제목: 생성형 AI와 블렌더, 언리얼엔진을 활용한 3D 비주얼 아티스트 양성과정 [3]
#   훈련기관: 애드인에듀 아카데미 구로가산센터 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-08-05 [3]
#   주소: 서울 금천구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 72.9 [3]
# --------------------
# --- 훈련과정 95 ---
#   제목: [이스트캠프] 와썹 AI 모델 개발(Python, 인공지능, 딥러닝) [3]
#   훈련기관: (주)이스트소프트 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-06-25 [3]
#   주소: 서울 서초구 [3]
#   수강비: 13213200 [3]
#   실제 훈련비: 13213200 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 79.4 [3]
# --------------------
# --- 훈련과정 96 ---
#   제목: AWS 풀스택 웹앱(자바, 스프링, 리액트) 지역산업기반 개발자 양성 [3]
#   훈련기관: 더조은컴퓨터학원 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-08-08 [3]
#   주소: 서울 구로구 [3]
#   수강비: 9493000 [3]
#   실제 훈련비: 9493000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 90.0 [3]
# --------------------
# --- 훈련과정 97 ---
#   제목: 빅데이터 서비스 구현을 위한 자바 파이썬 (Java, Python) 개발자 과정 [3]
#   훈련기관: 한국소프트웨어인재개발원 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-08-01 [3]
#   주소: 서울 금천구 [3]
#   수강비: 9113280 [3]
#   실제 훈련비: 9113280 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 74.3 [3]
# --------------------
# --- 훈련과정 98 ---
#   제목: 융합_[Oracle] 오라클 아카데미 바이오헬스 융합 데이터 분석가 트랙 [3]
#   훈련기관: 대한상공회의소 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-08-01 [3]
#   주소: 서울 중구 [3]
#   수강비: 17424000 [3]
#   실제 훈련비: 17424000 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 0 [3]
# --------------------
# --- 훈련과정 99 ---
#   제목: KT클라우드와 NHN Cloud로 완성하는 클라우드 엔지니어 양성 [3]
#   훈련기관: 한국정보교육원(구.경원직업전문학교) [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-08-04 [3]
#   주소: 서울 관악구 [3]
#   수강비: 9097920 [3]
#   실제 훈련비: 9097920 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 85.0 [3]
# --------------------
# --- 훈련과정 100 ---
#   제목: 기업맞춤형 AI+X 융복합 인재 양성 과정 [3]
#   훈련기관: (주)한국능률협회컨설팅 [3]
#   훈련 시작일: 2025-02-10 [3]
#   훈련 종료일: 2025-07-08 [3]
#   주소: 서울 마포구 [3]
#   수강비: 14955600 [3]
#   실제 훈련비: 14955600 [3]
#   취업률 (고용보험 3개월): N/A% [3]
#   만족도 점수: 78.0 [3]
# --------------------

# %%
training_list
# Out:
# [{'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '자바 스프링 리액트로 완성하는 클라우드 활용 풀스택 개발 ',
#   'realMan': '9477000',
#   'telNo': '02-855-9611',
#   'stdgScor': '92.2',
#   'traStartDate': '2025-01-02',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '19',
#   'trprDegr': '16',
#   'address': '서울 관악구',
#   'traEndDate': '2025-09-25',
#   'subTitle': '한국정보교육원(구.경원직업전문학교)',
#   'instCd': '200400659',
#   'trngAreaCd': '11350',
#   'trprId': 'AIG20230000412579',
#   'yardMan': '25',
#   'courseMan': '9477000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020031803',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412579&tracseTme=16&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412579&tracseTme=16&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'Tech 우수 인재를 위한 풀스택 과정, 한국경제신문 with toss bank (ML Ops 합동 프로젝트)',
#   'realMan': '17424000',
#   'telNo': '02-360-4880',
#   'stdgScor': '77.8',
#   'traStartDate': '2025-01-02',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '33',
#   'trprDegr': '2',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '한경아카데미',
#   'instCd': '200803084',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20240000458996',
#   'yardMan': '34',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020048219',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000458996&tracseTme=2&trainstCstmrId=500020048219&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000458996&tracseTme=2&trainstCstmrId=500020048219&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'Tech 우수 인재를 위한 ML Ops 과정, 한국경제신문 with toss bank (풀스택 합동 프로젝트)',
#   'realMan': '17424000',
#   'telNo': '02-360-4880',
#   'stdgScor': '85.2',
#   'traStartDate': '2025-01-02',
#   'grade': '',
#   'ncsCd': '20010703',
#   'regCourseMan': '31',
#   'trprDegr': '2',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '한경아카데미',
#   'instCd': '200803084',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20240000458997',
#   'yardMan': '34',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020048219',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000458997&tracseTme=2&trainstCstmrId=500020048219&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000458997&tracseTme=2&trainstCstmrId=500020048219&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[KG ICT] 청년 AI 로보틱스',
#   'realMan': '17569200',
#   'telNo': '02-6050-3938',
#   'stdgScor': '65.1',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '0',
#   'trprDegr': '27',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20230000455784',
#   'yardMan': '25',
#   'courseMan': '17569200',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455784&tracseTme=27&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455784&tracseTme=27&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[KG ICT] 청년 AI 로보틱스',
#   'realMan': '17569200',
#   'telNo': '02-6050-3938',
#   'stdgScor': '65.1',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '0',
#   'trprDegr': '24',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20230000455784',
#   'yardMan': '25',
#   'courseMan': '17569200',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455784&tracseTme=24&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455784&tracseTme=24&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '23',
#   'trprDegr': '15',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=15&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=15&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '17',
#   'trprDegr': '19',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=19&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=19&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'JAVA 기반 백엔드 개발자 양성',
#   'realMan': '17424000',
#   'telNo': '02-3397-1292',
#   'stdgScor': '85.6',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '19',
#   'trprDegr': '6',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-09',
#   'subTitle': '(주)신세계아이앤씨',
#   'instCd': '202201689',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000455609',
#   'yardMan': '30',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500041614685',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455609&tracseTme=6&trainstCstmrId=500041614685&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455609&tracseTme=6&trainstCstmrId=500041614685&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[KG ICT] 청년 AI 로보틱스',
#   'realMan': '17569200',
#   'telNo': '02-6050-3938',
#   'stdgScor': '65.1',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '0',
#   'trprDegr': '25',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20230000455784',
#   'yardMan': '25',
#   'courseMan': '17569200',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455784&tracseTme=25&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455784&tracseTme=25&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '20',
#   'trprDegr': '14',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=14&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=14&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '20',
#   'trprDegr': '16',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=16&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=16&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '18',
#   'trprDegr': '18',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=18&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=18&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '빅데이터 기반 컴퓨터비전(CV) 데이터사이언스 과정',
#   'realMan': '8999360',
#   'telNo': '02-861-8568',
#   'stdgScor': '81.0',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '20010105',
#   'regCourseMan': '7',
#   'trprDegr': '1',
#   'address': '서울 금천구',
#   'traEndDate': '2025-07-09',
#   'subTitle': '메디치교육센터 평생교육시설',
#   'instCd': '201402676',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20240000498272',
#   'yardMan': '20',
#   'courseMan': '8999360',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020016144',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498272&tracseTme=1&trainstCstmrId=500020016144&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498272&tracseTme=1&trainstCstmrId=500020016144&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[KG ICT] 청년 AI 로보틱스',
#   'realMan': '17569200',
#   'telNo': '02-6050-3938',
#   'stdgScor': '65.1',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '0',
#   'trprDegr': '26',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-02',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20230000455784',
#   'yardMan': '25',
#   'courseMan': '17569200',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455784&tracseTme=26&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455784&tracseTme=26&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[두산로보틱스] 지능형 로보틱스 엔지니어',
#   'realMan': '15336750',
#   'telNo': '02-6050-3938',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-01-06',
#   'grade': '',
#   'ncsCd': '19030803',
#   'regCourseMan': '18',
#   'trprDegr': '17',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-05',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459422',
#   'yardMan': '25',
#   'courseMan': '15336750',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459422&tracseTme=17&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459422&tracseTme=17&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'SK네트웍스 Family AI 캠프',
#   'realMan': '17424000',
#   'telNo': '02-754-7302',
#   'stdgScor': '80.4',
#   'traStartDate': '2025-01-07',
#   'grade': '',
#   'ncsCd': '20010703',
#   'regCourseMan': '30',
#   'trprDegr': '10',
#   'address': '서울 서초구',
#   'traEndDate': '2025-07-07',
#   'subTitle': '플레이데이터평생교육원',
#   'instCd': '200200543',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20240000459068',
#   'yardMan': '30',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020011379',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459068&tracseTme=10&trainstCstmrId=500020011379&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459068&tracseTme=10&trainstCstmrId=500020011379&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'ChatGPT를 활용한 AI 웹앱(자바,파이썬) 서비스 개발자 양성 과정',
#   'realMan': '9113280',
#   'telNo': '02-6020-0055',
#   'stdgScor': '87.3',
#   'traStartDate': '2025-01-07',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '14',
#   'trprDegr': '1',
#   'address': '서울 관악구',
#   'traEndDate': '2025-07-09',
#   'subTitle': '글로벌아이티(IT)인재개발학원',
#   'instCd': '200600295',
#   'trngAreaCd': '11620',
#   'trprId': 'AIG20240000498126',
#   'yardMan': '25',
#   'courseMan': '9113280',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020055899',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498126&tracseTme=1&trainstCstmrId=500020055899&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498126&tracseTme=1&trainstCstmrId=500020055899&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '자바(JAVA) 웹개발자 양성과정(클라우드)',
#   'realMan': '9113280',
#   'telNo': '02-2233-6417',
#   'stdgScor': '89.8',
#   'traStartDate': '2025-01-07',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '17',
#   'trprDegr': '2',
#   'address': '서울 마포구',
#   'traEndDate': '2025-07-11',
#   'subTitle': '에이콘아카데미 홍대학원',
#   'instCd': '201001671',
#   'trngAreaCd': '11440',
#   'trprId': 'AIG20240000459242',
#   'yardMan': '30',
#   'courseMan': '9113280',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020038200',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459242&tracseTme=2&trainstCstmrId=500020038200&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459242&tracseTme=2&trainstCstmrId=500020038200&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드기반 스마트 융합보안 과정',
#   'realMan': '17424000',
#   'telNo': '031-5180-5256',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-07',
#   'grade': '',
#   'ncsCd': '20010602',
#   'regCourseMan': '49',
#   'trprDegr': '1',
#   'address': '경기 성남시 분당구',
#   'traEndDate': '2025-07-24',
#   'subTitle': '인포섹 아카데미',
#   'instCd': '201200313',
#   'trngAreaCd': '11140',
#   'trprId': 'AIG20240000498287',
#   'yardMan': '50',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020056274',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498287&tracseTme=1&trainstCstmrId=500020056274&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498287&tracseTme=1&trainstCstmrId=500020056274&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드 기반의 자바 풀스택 (Springboot, React, flutter) 개발자',
#   'realMan': '9097920',
#   'telNo': '02-3478-0008',
#   'stdgScor': '93.7',
#   'traStartDate': '2025-01-08',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '17',
#   'trprDegr': '9',
#   'address': '서울 서초구',
#   'traEndDate': '2025-07-03',
#   'subTitle': '하이미디어아카데미',
#   'instCd': '200601104',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20230000412819',
#   'yardMan': '20',
#   'courseMan': '9097920',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020056026',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412819&tracseTme=9&trainstCstmrId=500020056026&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412819&tracseTme=9&trainstCstmrId=500020056026&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '심화_ROS2와 AI를 활용한 자율주행&로봇팔 개발자 부트캠프',
#   'realMan': '5123320',
#   'telNo': '02-552-8565',
#   'stdgScor': '89.7',
#   'traStartDate': '2025-01-13',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '3',
#   'address': '서울 금천구',
#   'traEndDate': '2025-03-19',
#   'subTitle': '애드인에듀 아카데미 구로가산센터',
#   'instCd': '202100786',
#   'trngAreaCd': '11200',
#   'trprId': 'AIG20240000459108',
#   'yardMan': '30',
#   'courseMan': '5123320',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500039029321',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459108&tracseTme=3&trainstCstmrId=500039029321&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459108&tracseTme=3&trainstCstmrId=500039029321&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'AWS와 Docker & Kubernetes를 활용한 Java Full-Stack 개발자 양성과정',
#   'realMan': '9856080',
#   'telNo': '02-3482-4633',
#   'stdgScor': '95.1',
#   'traStartDate': '2025-01-13',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '7',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-29',
#   'subTitle': '쌍용교육센터',
#   'instCd': '200500853',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000412645',
#   'yardMan': '30',
#   'courseMan': '9856080',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020052430',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412645&tracseTme=7&trainstCstmrId=500020052430&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412645&tracseTme=7&trainstCstmrId=500020052430&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'HIWARE로 완성하는 클라우드 IT 인프라 보안 엔지니어 양성',
#   'realMan': '9097920',
#   'telNo': '02-855-9611',
#   'stdgScor': '88.4',
#   'traStartDate': '2025-01-13',
#   'grade': '',
#   'ncsCd': '20010301',
#   'regCourseMan': '20',
#   'trprDegr': '5',
#   'address': '서울 관악구',
#   'traEndDate': '2025-07-10',
#   'subTitle': '한국정보교육원(구.경원직업전문학교)',
#   'instCd': '200400659',
#   'trngAreaCd': '11620',
#   'trprId': 'AIG20230000455731',
#   'yardMan': '25',
#   'courseMan': '9097920',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020031803',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455731&tracseTme=5&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455731&tracseTme=5&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'Cisco VirtuNet Cloud 통합 구현',
#   'realMan': '17424000',
#   'telNo': '02-6240-4884',
#   'stdgScor': '90.6',
#   'traStartDate': '2025-01-14',
#   'grade': '',
#   'ncsCd': '20010301',
#   'regCourseMan': '30',
#   'trprDegr': '5',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-22',
#   'subTitle': '한국표준협회',
#   'instCd': '200602001',
#   'trngAreaCd': '11110',
#   'trprId': 'AIG20230000455741',
#   'yardMan': '30',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020055650',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455741&tracseTme=5&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455741&tracseTme=5&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '챗GPT를 활용한 자바(JAVA) 스프링 및 데이터 분석 시스템기반 웹 플랫폼 구축 과정',
#   'realMan': '9872720',
#   'telNo': '02-2138-3275',
#   'stdgScor': '96.6',
#   'traStartDate': '2025-01-14',
#   'grade': '',
#   'ncsCd': '20010209',
#   'regCourseMan': '17',
#   'trprDegr': '3',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-29',
#   'subTitle': '솔데스크강남학원',
#   'instCd': '201800007',
#   'trngAreaCd': '11320',
#   'trprId': 'AIG20240000459042',
#   'yardMan': '30',
#   'courseMan': '9872720',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500034091717',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459042&tracseTme=3&trainstCstmrId=500034091717&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459042&tracseTme=3&trainstCstmrId=500034091717&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '프로그래머스 데브코스: 생성형 AI활용 백엔드 개발',
#   'realMan': '17424000',
#   'telNo': '--',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-15',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '38',
#   'trprDegr': '1',
#   'address': '서울 서초구',
#   'traEndDate': '2025-07-18',
#   'subTitle': '(주)그렙',
#   'instCd': '201902529',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20240000498288',
#   'yardMan': '60',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500036172479',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498288&tracseTme=1&trainstCstmrId=500036172479&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498288&tracseTme=1&trainstCstmrId=500036172479&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '콘텐츠 융합을 위한 자바(JAVA)기반  Full Stack 개발자 양성과정',
#   'realMan': '9097920',
#   'telNo': '02-539-8879',
#   'stdgScor': '86.2',
#   'traStartDate': '2025-01-15',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '14',
#   'trprDegr': '10',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-10',
#   'subTitle': '에이콘아카데미(강남)',
#   'instCd': '200900920',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000412712',
#   'yardMan': '30',
#   'courseMan': '9097920',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020033277',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412712&tracseTme=10&trainstCstmrId=500020033277&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412712&tracseTme=10&trainstCstmrId=500020033277&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '프로젝트 기반 풀스택(프론트/백엔드) 개발자 취업캠프(리액트,자바,스프링부트)',
#   'realMan': '11448550',
#   'telNo': '02-766-8368',
#   'stdgScor': '98.2',
#   'traStartDate': '2025-01-15',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '18',
#   'trprDegr': '2',
#   'address': '서울 종로구',
#   'traEndDate': '2025-09-01',
#   'subTitle': '더조은컴퓨터아카데미 종로',
#   'instCd': '200801979',
#   'trngAreaCd': '11110',
#   'trprId': 'AIG20240000459122',
#   'yardMan': '20',
#   'courseMan': '11448550',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020027870',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459122&tracseTme=2&trainstCstmrId=500020027870&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459122&tracseTme=2&trainstCstmrId=500020027870&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '심화_프론트엔드 엔지니어 부트캠프',
#   'realMan': '5097490',
#   'telNo': '--',
#   'stdgScor': '85.5',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '37',
#   'trprDegr': '7',
#   'address': '서울 강남구',
#   'traEndDate': '2025-03-18',
#   'subTitle': '코드잇 평생교육원',
#   'instCd': '202204937',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459335',
#   'yardMan': '80',
#   'courseMan': '5097490',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500042496680',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459335&tracseTme=7&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459335&tracseTme=7&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드 기반 풀스택 엔지니어 부트캠프',
#   'realMan': '22687500',
#   'telNo': '--',
#   'stdgScor': '85.3',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '31',
#   'trprDegr': '6',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-19',
#   'subTitle': '코드잇 평생교육원',
#   'instCd': '202204937',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459283',
#   'yardMan': '80',
#   'courseMan': '22687500',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500042496680',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459283&tracseTme=6&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459283&tracseTme=6&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드 가상화 기반 자바(JAVA) 개발자 양성과정',
#   'realMan': '9173730',
#   'telNo': '02-6255-8002',
#   'stdgScor': '86.2',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '0',
#   'trprDegr': '5',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-15',
#   'subTitle': '아이티윌',
#   'instCd': '200702472',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000412856',
#   'yardMan': '30',
#   'courseMan': '9173730',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020051277',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412856&tracseTme=5&trainstCstmrId=500020051277&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412856&tracseTme=5&trainstCstmrId=500020051277&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'MSA기반 자바 백엔드 개발자 양성과정',
#   'realMan': '9189220',
#   'telNo': '02-6255-8002',
#   'stdgScor': '71.4',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '11',
#   'trprDegr': '3',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-22',
#   'subTitle': '아이티윌',
#   'instCd': '200702472',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459194',
#   'yardMan': '30',
#   'courseMan': '9189220',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020051277',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459194&tracseTme=3&trainstCstmrId=500020051277&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459194&tracseTme=3&trainstCstmrId=500020051277&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드 기반 Node.js 백엔드 엔지니어 부트캠프',
#   'realMan': '22687500',
#   'telNo': '--',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '17',
#   'trprDegr': '1',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-18',
#   'subTitle': '코드잇 평생교육원',
#   'instCd': '202204937',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000498130',
#   'yardMan': '60',
#   'courseMan': '22687500',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500042496680',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498130&tracseTme=1&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498130&tracseTme=1&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '융합_빅데이터를 활용한 디지털금융 전문가',
#   'realMan': '16298700',
#   'telNo': '02-1588-1381',
#   'stdgScor': '78.6',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010105',
#   'regCourseMan': '32',
#   'trprDegr': '1',
#   'address': '서울 구로구',
#   'traEndDate': '2025-07-09',
#   'subTitle': '유비온디지털교육센터',
#   'instCd': '202102335',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000498402',
#   'yardMan': '36',
#   'courseMan': '16298700',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500039652243',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498402&tracseTme=1&trainstCstmrId=500039652243&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498402&tracseTme=1&trainstCstmrId=500039652243&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'AI 활용 데이터 분석가 부트캠프',
#   'realMan': '22687500',
#   'telNo': '--',
#   'stdgScor': '86.0',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010105',
#   'regCourseMan': '68',
#   'trprDegr': '6',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-14',
#   'subTitle': '코드잇 평생교육원',
#   'instCd': '202204937',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459302',
#   'yardMan': '80',
#   'courseMan': '22687500',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500042496680',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459302&tracseTme=6&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459302&tracseTme=6&trainstCstmrId=500042496680&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'IaC 기반 하이브리드 클라우드 인프라 및 보안 솔루션 구축 과정',
#   'realMan': '9189220',
#   'telNo': '02-588-9991',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-16',
#   'grade': '',
#   'ncsCd': '20010612',
#   'regCourseMan': '20',
#   'trprDegr': '1',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-21',
#   'subTitle': '메가스터디아이티(IT)아카데미학원',
#   'instCd': '201902267',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000498209',
#   'yardMan': '20',
#   'courseMan': '9189220',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500036090856',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498209&tracseTme=1&trainstCstmrId=500036090856&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498209&tracseTme=1&trainstCstmrId=500036090856&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'VR을 활용한 실감형 콘텐츠 제작자 양성과정',
#   'realMan': '9113280',
#   'telNo': '02-2675-1750',
#   'stdgScor': '61.9',
#   'traStartDate': '2025-01-17',
#   'grade': '',
#   'ncsCd': '08020112',
#   'regCourseMan': '22',
#   'trprDegr': '4',
#   'address': '서울 강서구',
#   'traEndDate': '2025-07-15',
#   'subTitle': '엠비씨(MBC)아카데미 컴퓨터교육센터 화곡점',
#   'instCd': '200701729',
#   'trngAreaCd': '11500',
#   'trprId': 'AIG20240000459278',
#   'yardMan': '30',
#   'courseMan': '9113280',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020044103',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459278&tracseTme=4&trainstCstmrId=500020044103&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459278&tracseTme=4&trainstCstmrId=500020044103&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[기업프로젝트] 메타버스 게임 개발자 양성',
#   'realMan': '10632160',
#   'telNo': '070-5118-0755',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-17',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '25',
#   'trprDegr': '1',
#   'address': '서울 강동구',
#   'traEndDate': '2025-08-14',
#   'subTitle': '주식회사경일게임아이티아카데미',
#   'instCd': '200400746',
#   'trngAreaCd': '11740',
#   'trprId': 'AIG20240000498331',
#   'yardMan': '30',
#   'courseMan': '10632160',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020031484',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498331&tracseTme=1&trainstCstmrId=500020031484&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498331&tracseTme=1&trainstCstmrId=500020031484&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '융합_프로젝트 기반 에듀테크 기획자',
#   'realMan': '7081770',
#   'telNo': '02-1588-1381',
#   'stdgScor': '71.4',
#   'traStartDate': '2025-01-17',
#   'grade': '',
#   'ncsCd': '20010105',
#   'regCourseMan': '7',
#   'trprDegr': '1',
#   'address': '서울 구로구',
#   'traEndDate': '2025-06-13',
#   'subTitle': '유비온디지털교육센터',
#   'instCd': '202102335',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000498405',
#   'yardMan': '30',
#   'courseMan': '7081770',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500039652243',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498405&tracseTme=1&trainstCstmrId=500039652243&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498405&tracseTme=1&trainstCstmrId=500039652243&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '엘리스 QA 자동화 엔지니어 트랙',
#   'realMan': '11979000',
#   'telNo': '02-1833-6068',
#   'stdgScor': '63.5',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '31',
#   'trprDegr': '1',
#   'address': '서울 강남구',
#   'traEndDate': '2025-05-20',
#   'subTitle': '(주)엘리스그룹',
#   'instCd': '202003272',
#   'trngAreaCd': '11200',
#   'trprId': 'AIG20240000498101',
#   'yardMan': '50',
#   'courseMan': '11979000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500038398274',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498101&tracseTme=1&trainstCstmrId=500038398274&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498101&tracseTme=1&trainstCstmrId=500038398274&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '백엔드 개발자 부트캠프(스프링)',
#   'realMan': '14229600',
#   'telNo': '02-1544-9001',
#   'stdgScor': '91.0',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '18',
#   'trprDegr': '2',
#   'address': '서울 강남구',
#   'traEndDate': '2025-06-17',
#   'subTitle': '멀티캠퍼스',
#   'instCd': '200400649',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000498279',
#   'yardMan': '28',
#   'courseMan': '14229600',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039927',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498279&tracseTme=2&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498279&tracseTme=2&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[LG유플러스] 유레카 백엔드 개발자',
#   'realMan': '19602000',
#   'telNo': '02-1544-9001',
#   'stdgScor': '89.8',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '4',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-12',
#   'subTitle': '멀티캠퍼스',
#   'instCd': '200400649',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459164',
#   'yardMan': '30',
#   'courseMan': '19602000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039927',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459164&tracseTme=4&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459164&tracseTme=4&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[LG유플러스] 유레카 프론트엔드 개발자',
#   'realMan': '19602000',
#   'telNo': '02-1544-9001',
#   'stdgScor': '75.4',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '4',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-12',
#   'subTitle': '멀티캠퍼스',
#   'instCd': '200400649',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459339',
#   'yardMan': '30',
#   'courseMan': '19602000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039927',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459339&tracseTme=4&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459339&tracseTme=4&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'AI MSP 베스핀글로벌의 멀티클라우드(AWS·Azure·GCP·NCP) 엔지니어 부트캠프',
#   'realMan': '18150000',
#   'telNo': '02-6951-5092',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010215',
#   'regCourseMan': '21',
#   'trprDegr': '1',
#   'address': '서울 서초구',
#   'traEndDate': '2025-07-30',
#   'subTitle': '베스핀글로벌주식회사',
#   'instCd': '202201809',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000498368',
#   'yardMan': '30',
#   'courseMan': '18150000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500041642929',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498368&tracseTme=1&trainstCstmrId=500041642929&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498368&tracseTme=1&trainstCstmrId=500041642929&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[스타트업][스마트훈련]실무형 UX/UI 디자이너 양성과정',
#   'realMan': '17424000',
#   'telNo': '02-1522-8016',
#   'stdgScor': '82.2',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010207',
#   'regCourseMan': '115',
#   'trprDegr': '6',
#   'address': '서울 강남구',
#   'traEndDate': '2025-05-30',
#   'subTitle': '팀스파르타주식회사',
#   'instCd': '202101540',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000455653',
#   'yardMan': '150',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500039286716',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455653&tracseTme=6&trainstCstmrId=500039286716&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455653&tracseTme=6&trainstCstmrId=500039286716&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[Unity] 유니티 부트캠프',
#   'realMan': '17424000',
#   'telNo': '02-6050-3938',
#   'stdgScor': '70.6',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20020401',
#   'regCourseMan': '24',
#   'trprDegr': '12',
#   'address': '서울 중구',
#   'traEndDate': '2025-07-21',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20230000412895',
#   'yardMan': '25',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412895&tracseTme=12&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412895&tracseTme=12&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[LG유플러스] 유레카 백엔드 개발자',
#   'realMan': '19602000',
#   'telNo': '02-1544-9001',
#   'stdgScor': '89.8',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '3',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-12',
#   'subTitle': '멀티캠퍼스',
#   'instCd': '200400649',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459164',
#   'yardMan': '30',
#   'courseMan': '19602000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039927',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459164&tracseTme=3&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459164&tracseTme=3&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[LG유플러스] 유레카 프론트엔드 개발자',
#   'realMan': '19602000',
#   'telNo': '02-1544-9001',
#   'stdgScor': '75.4',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '30',
#   'trprDegr': '3',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-12',
#   'subTitle': '멀티캠퍼스',
#   'instCd': '200400649',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20240000459339',
#   'yardMan': '30',
#   'courseMan': '19602000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039927',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459339&tracseTme=3&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459339&tracseTme=3&trainstCstmrId=500020039927&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '인공지능(AI)활용 서비스 개발자(프론트엔드_React) 취업과정',
#   'realMan': '9872720',
#   'telNo': '02-766-8368',
#   'stdgScor': '0',
#   'traStartDate': '2025-01-20',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '7',
#   'trprDegr': '1',
# ...
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[가비아] g클라우드 기반의 그룹웨어 개발자 양성과정',
#   'realMan': '18150000',
#   'telNo': '02-6240-4884',
#   'stdgScor': '0',
#   'traStartDate': '2025-02-04',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '26',
#   'trprDegr': '1',
#   'address': '서울 강남구',
#   'traEndDate': '2025-08-08',
#   'subTitle': '한국표준협회',
#   'instCd': '200602001',
#   'trngAreaCd': '11110',
#   'trprId': 'AIG20240000501197',
#   'yardMan': '30',
#   'courseMan': '18150000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020055650',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000501197&tracseTme=1&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000501197&tracseTme=1&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'AI/빅데이터를 활용한 사이버보안 위협 탐지기술 개발자 양성과정',
#   'realMan': '14520000',
#   'telNo': '02-6240-4884',
#   'stdgScor': '79.4',
#   'traStartDate': '2025-02-05',
#   'grade': '',
#   'ncsCd': '20010603',
#   'regCourseMan': '19',
#   'trprDegr': '3',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-07',
#   'subTitle': '한국표준협회',
#   'instCd': '200602001',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20230000455743',
#   'yardMan': '40',
#   'courseMan': '14520000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020055650',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455743&tracseTme=3&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455743&tracseTme=3&trainstCstmrId=500020055650&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '웹 서비스 프로젝트 기반 프론트엔드 엔지니어 부트캠프',
#   'realMan': '16698000',
#   'telNo': '02-6203-7222',
#   'stdgScor': '91.1',
#   'traStartDate': '2025-02-05',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '70',
#   'trprDegr': '2',
#   'address': '서울 종로구',
#   'traEndDate': '2025-08-08',
#   'subTitle': '주식회사멋쟁이사자처럼',
#   'instCd': '202002424',
#   'trngAreaCd': '11110',
#   'trprId': 'AIG20240000459331',
#   'yardMan': '70',
#   'courseMan': '16698000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037933544',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459331&tracseTme=2&trainstCstmrId=500037933544&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459331&tracseTme=2&trainstCstmrId=500037933544&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '클라우드 데브옵스 프론트엔드&백엔드 자바(JAVA) 풀스택 개발자 취업캠프',
#   'realMan': '9097920',
#   'telNo': '02-561-1911',
#   'stdgScor': '90.9',
#   'traStartDate': '2025-02-05',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '13',
#   'trprDegr': '9',
#   'address': '서울 강남구',
#   'traEndDate': '2025-07-29',
#   'subTitle': '중앙정보기술인재개발원',
#   'instCd': '200400336',
#   'trngAreaCd': '11680',
#   'trprId': 'AIG20230000455640',
#   'yardMan': '30',
#   'courseMan': '9097920',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020039773',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455640&tracseTme=9&trainstCstmrId=500020039773&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455640&tracseTme=9&trainstCstmrId=500020039773&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '(현대로템) K-방산 AI모델 개발과정',
#   'realMan': '17424000',
#   'telNo': '02-317-6183',
#   'stdgScor': '71.1',
#   'traStartDate': '2025-02-05',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '26',
#   'trprDegr': '3',
#   'address': '서울 양천구',
#   'traEndDate': '2025-07-24',
#   'subTitle': '한국전파진흥협회',
#   'instCd': '201000256',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20240000459125',
#   'yardMan': '30',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020053280',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459125&tracseTme=3&trainstCstmrId=500020053280&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459125&tracseTme=3&trainstCstmrId=500020053280&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '카티아 로보틱스 설계와 유니티 스마트팩토리 가상구현',
#   'realMan': '12210000',
#   'telNo': '02-2038-0800',
#   'stdgScor': '91.8',
#   'traStartDate': '2025-02-06',
#   'grade': '',
#   'ncsCd': '15110101',
#   'regCourseMan': '28',
#   'trprDegr': '5',
#   'address': '서울 금천구',
#   'traEndDate': '2025-08-06',
#   'subTitle': '코드랩아카데미학원',
#   'instCd': '201700357',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20230000455631',
#   'yardMan': '30',
#   'courseMan': '12210000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020059024',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455631&tracseTme=5&trainstCstmrId=500020059024&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455631&tracseTme=5&trainstCstmrId=500020059024&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[부트캠프]AI 인공지능 웹서비스 풀스택 개발자(AICC딥러닝)',
#   'realMan': '12210000',
#   'telNo': '02-2038-0800',
#   'stdgScor': '83.4',
#   'traStartDate': '2025-02-06',
#   'grade': '',
#   'ncsCd': '20010705',
#   'regCourseMan': '16',
#   'trprDegr': '5',
#   'address': '서울 금천구',
#   'traEndDate': '2025-08-05',
#   'subTitle': '코드랩아카데미학원',
#   'instCd': '201700357',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20230000455630',
#   'yardMan': '30',
#   'courseMan': '12210000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020059024',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455630&tracseTme=5&trainstCstmrId=500020059024&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455630&tracseTme=5&trainstCstmrId=500020059024&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'SK네트웍스 Family AI 캠프',
#   'realMan': '17424000',
#   'telNo': '02-754-7302',
#   'stdgScor': '80.4',
#   'traStartDate': '2025-02-07',
#   'grade': '',
#   'ncsCd': '20010703',
#   'regCourseMan': '30',
#   'trprDegr': '11',
#   'address': '서울 서초구',
#   'traEndDate': '2025-08-01',
#   'subTitle': '플레이데이터평생교육원',
#   'instCd': '200200543',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20240000459068',
#   'yardMan': '30',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020011379',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459068&tracseTme=11&trainstCstmrId=500020011379&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459068&tracseTme=11&trainstCstmrId=500020011379&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '바이오헬스 실무 전문과정',
#   'realMan': '11470800',
#   'telNo': '02-450-4249',
#   'stdgScor': '66.3',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '17050107',
#   'regCourseMan': '39',
#   'trprDegr': '2',
#   'address': '서울 광진구',
#   'traEndDate': '2025-07-11',
#   'subTitle': '건국대학교산학협력단',
#   'instCd': '201100970',
#   'trngAreaCd': '11215',
#   'trprId': 'AIG20240000459236',
#   'yardMan': '40',
#   'courseMan': '11470800',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020050660',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459236&tracseTme=2&trainstCstmrId=500020050660&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459236&tracseTme=2&trainstCstmrId=500020050660&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '생성형 AI와 블렌더, 언리얼엔진을 활용한 3D 비주얼 아티스트 양성과정',
#   'realMan': '9113280',
#   'telNo': '02-552-8565',
#   'stdgScor': '72.9',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20020401',
#   'regCourseMan': '28',
#   'trprDegr': '2',
#   'address': '서울 금천구',
#   'traEndDate': '2025-08-05',
#   'subTitle': '애드인에듀 아카데미 구로가산센터',
#   'instCd': '202100786',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20240000459366',
#   'yardMan': '30',
#   'courseMan': '9113280',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500039029321',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459366&tracseTme=2&trainstCstmrId=500039029321&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459366&tracseTme=2&trainstCstmrId=500039029321&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '[이스트캠프] 와썹 AI 모델 개발(Python, 인공지능, 딥러닝)',
#   'realMan': '13213200',
#   'telNo': '',
#   'stdgScor': '79.4',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010703',
#   'regCourseMan': '38',
#   'trprDegr': '9',
#   'address': '서울 서초구',
#   'traEndDate': '2025-06-25',
#   'subTitle': '(주)이스트소프트',
#   'instCd': '201902006',
#   'trngAreaCd': '11650',
#   'trprId': 'AIG20230000455595',
#   'yardMan': '80',
#   'courseMan': '13213200',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500035988371',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455595&tracseTme=9&trainstCstmrId=500035988371&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455595&tracseTme=9&trainstCstmrId=500035988371&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'AWS 풀스택 웹앱(자바, 스프링, 리액트) 지역산업기반 개발자 양성',
#   'realMan': '9493000',
#   'telNo': '02-838-1689',
#   'stdgScor': '90.0',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '11',
#   'trprDegr': '5',
#   'address': '서울 구로구',
#   'traEndDate': '2025-08-08',
#   'subTitle': '더조은컴퓨터학원',
#   'instCd': '200701052',
#   'trngAreaCd': '11530',
#   'trprId': 'AIG20240000459360',
#   'yardMan': '25',
#   'courseMan': '9493000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020061827',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459360&tracseTme=5&trainstCstmrId=500020061827&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459360&tracseTme=5&trainstCstmrId=500020061827&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '빅데이터 서비스 구현을 위한 자바 파이썬 (Java, Python) 개발자 과정',
#   'realMan': '9113280',
#   'telNo': '02-2025-8523',
#   'stdgScor': '74.3',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '21',
#   'trprDegr': '2',
#   'address': '서울 금천구',
#   'traEndDate': '2025-08-01',
#   'subTitle': '한국소프트웨어인재개발원',
#   'instCd': '201002230',
#   'trngAreaCd': '11545',
#   'trprId': 'AIG20240000498081',
#   'yardMan': '30',
#   'courseMan': '9113280',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020027783',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000498081&tracseTme=2&trainstCstmrId=500020027783&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000498081&tracseTme=2&trainstCstmrId=500020027783&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '융합_[Oracle] 오라클 아카데미 바이오헬스 융합 데이터 분석가 트랙',
#   'realMan': '17424000',
#   'telNo': '02-6050-3938',
#   'stdgScor': '0',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010107',
#   'regCourseMan': '50',
#   'trprDegr': '1',
#   'address': '서울 중구',
#   'traEndDate': '2025-08-01',
#   'subTitle': '대한상공회의소',
#   'instCd': '202001423',
#   'trngAreaCd': '11200',
#   'trprId': 'AIG20240000501255',
#   'yardMan': '50',
#   'courseMan': '17424000',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500037517077',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000501255&tracseTme=1&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000501255&tracseTme=1&trainstCstmrId=500037517077&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': 'KT클라우드와 NHN Cloud로 완성하는 클라우드 엔지니어 양성',
#   'realMan': '9097920',
#   'telNo': '02-855-9611',
#   'stdgScor': '85.0',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010301',
#   'regCourseMan': '21',
#   'trprDegr': '8',
#   'address': '서울 관악구',
#   'traEndDate': '2025-08-04',
#   'subTitle': '한국정보교육원(구.경원직업전문학교)',
#   'instCd': '200400659',
#   'trngAreaCd': '11620',
#   'trprId': 'AIG20230000455736',
#   'yardMan': '25',
#   'courseMan': '9097920',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020031803',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000455736&tracseTme=8&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000455736&tracseTme=8&trainstCstmrId=500020031803&crseTracseSe=C0061',
#   'titleIcon': ''},
#  {'eiEmplCnt3Gt10': '',
#   'eiEmplRate6': '',
#   'eiEmplCnt3': '',
#   'eiEmplRate3': '',
#   'certificate': '',
#   'title': '기업맞춤형 AI+X 융복합 인재 양성 과정',
#   'realMan': '14955600',
#   'telNo': '02-3786-0625',
#   'stdgScor': '78.0',
#   'traStartDate': '2025-02-10',
#   'grade': '',
#   'ncsCd': '20010202',
#   'regCourseMan': '27',
#   'trprDegr': '2',
#   'address': '서울 마포구',
#   'traEndDate': '2025-07-08',
#   'subTitle': '(주)한국능률협회컨설팅',
#   'instCd': '200200081',
#   'trngAreaCd': '11620',
#   'trprId': 'AIG20240000459209',
#   'yardMan': '30',
#   'courseMan': '14955600',
#   'trainTarget': 'K-디지털 트레이닝',
#   'trainTargetCd': 'C0104',
#   'trainstCstId': '500020024317',
#   'contents': '',
#   'subTitleLink': 'https://hrd.work24.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20240000459209&tracseTme=2&trainstCstmrId=500020024317&crseTracseSe=C0061',
#   'titleLink': 'https://hrd.work24.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20240000459209&tracseTme=2&trainstCstmrId=500020024317&crseTracseSe=C0061',
#   'titleIcon': ''}]

# %%
import pandas as pd

df=pd.read_csv('./훈련과정_전체데이터.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df=pd.read_csv('./훈련과정_전체데이터.csv')
#       4 df
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\ITStudy\01_python\00_streamlit\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './훈련과정_전체데이터.csv'
